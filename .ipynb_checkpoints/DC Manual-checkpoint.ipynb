# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
! pip install geopy
#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

import geocoder # import geocoder
import math
import re
print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in /Users/isalau/miniconda3/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /Users/isalau/miniconda3/lib/python3.8/site-packages (from geopy) (1.50)
# Libraries imported.

# %%
CLIENT_ID = 'YA1V0ZT4RLWE3PVLWULDI0QLPHCUNN0BNXSOT5GS3P1EZR0G' # your Foursquare ID
CLIENT_SECRET = 'ITTIADOFH3REMVNUNONWLMRG0T2051ETQD5GCDGDXBWNRJY5' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: YA1V0ZT4RLWE3PVLWULDI0QLPHCUNN0BNXSOT5GS3P1EZR0G
# CLIENT_SECRET:ITTIADOFH3REMVNUNONWLMRG0T2051ETQD5GCDGDXBWNRJY5

# %%
path = "/Users/isalau/Documents/GitHub/Coursera_Capstone/Neighborhood_Labels.csv"
dc = pd.read_csv(path)

# %%
dc = dc.rename({'X': 'Longitude'}, axis='columns')
dc = dc.rename({'Y': 'Latitude'}, axis='columns')
dc = dc.rename({'NAME': 'Neighborhood'}, axis='columns')

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500, LIMIT=100):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
names=dc['Neighborhood']
latitudes=dc['Latitude']
longitudes=dc['Longitude']
radius=500
LIMIT=100
for name, lat, lng in zip(names, latitudes, longitudes):            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]

# %%
path = "/Users/isalau/Documents/GitHub/Coursera_Capstone/dc_venues.csv"
dc_venues_from_csv= pd.read_csv(path)
dc_venues_from_csv.head()
dc_venues = dc_venues_from_csv

# %%
# dc_venues = getNearbyVenues(names=dc['Neighborhood'],
#                                    latitudes=dc['Latitude'],
#                                    longitudes=dc['Longitude']
#                                   )
# dc_venues.to_csv('dc_venues.csv', index=False, header=True)

# %%
dc_venues.groupby('Neighborhood').count()
print('There are {} uniques categories.'.format(len(dc_venues['Venue Category'].unique())))
# Out:
# There are 308 uniques categories.

# %%
# one hot encoding
dc_onehot = pd.get_dummies(dc_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
dc_onehot['Neighborhood'] = dc_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [dc_onehot.columns[-1]] + list(dc_onehot.columns[:-1])
dc_onehot = dc_onehot[fixed_columns]

# %%
dc_grouped = dc_onehot.groupby('Neighborhood').mean().reset_index()

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = dc_grouped['Neighborhood']

for ind in np.arange(dc_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(dc_grouped.iloc[ind, :], num_top_venues)

# %% [markdown]
# # Manully Cluster Neighborhoods

# %%
# each neighborhood has an overall residential, industrial and tousit count
# each neighborhood has an overall label 
# for each neighborhood 
#     count how many residential, industrial and tousit establishments there are. 
#     if an establishment is labeled as rtboth it gets a point in both residential and tourist. 
#     neighborhood is assigned label based on majority of establishments. 
#     if tie, break arbitrarly ---> priint these 

# cluster neighborhoods based on labels

# %%
# categories = dc_venues
# test = categories.drop(['Neighborhood Latitude','Neighborhood Longitude', 'Venue Latitude','Venue Longitude'], axis=1)
# print('There are originally {} uniques categories.'.format(len(test['Venue Category'].unique())))

# %% [markdown]
# General venue categories relabeled

# %%
def rename_labels(cat):
    #Residential
    Grocery = ['Tea','Bakery','Bagel Shop','Candy Store','Chocolate Shop','Convenience Store','Cupcake Shop','Deli / Bodega','Dessert Shop','Donut Shop','Drugstore','Farmers Market','Food,Food & Drink Shop','Gourmet Shop','Grocery Store','Liquor Store','Market','Organic Grocery','Pharmacy','Smoothie Shop','Snack Place','Supermarket','Supplement Shop','Wine Shop','Beer Store']
    Health = ['Chiropractor','Health & Beauty Service','Hospital','Massage Studio','Nail Salon','Spa','Salon / Barbershop']
    Home = ['Dog Run','Dry Cleaner','Home Service','Laundromat','Locksmith','Moving Target','Other Repair Shop','Pet Service','Shoe Repair','Storage Facility','Tailor Shop','Residential Building (Apartment / Condo)']
    Sports = ['Athletics & Sports','Baseball Field','Basketball Court','Basketball Stadium','Boxing Gym','Cycle Studio','Dance Studio','Field','Golf Course','Gym','Gym / Fitness Center','Gym Pool','Gymnastics Gym','Harbor / Marina','Heliport','Lake','Martial Arts School','Pilates Studio','Playground','Skating Rink','Soccer Field','Soccer Stadium','Sports Club','State / Provincial Park','Volleyball Court','Yoga Studio','Recreation Center','Track','Tennis Court']

    #Residential/Tourism 
    Shopping=['Accessories Store','Antique Shop','Arts & Crafts Store','Automotive Shop','Big Box Store','Bookstore','Boutique','Camera Store','Christmas Market','Clothing Store','Comic Shop','Cosmetics Shop','Department Store','Discount Store','Electronics Store','Flea Market','Flower Shop','Furniture / Home Store','Gift Shop','Hardware Store','Herbs & Spices Store','Jewelry Store','Kids Store','Kitchen Supply Store','Leather Goods Store','Lingerie Store','Mattress Store',"Men/'s Store",'Miscellaneous Shop','Mobile Phone Shop','Music Store','Optical Shop','Paper / Office Supplies Store','Pet Store','Photography Lab','Record Shop','Shipping Store','Shoe Store','Shop & Service','Shopping Mall','Shopping Plaza','Smoke Shop','Souvenir Shop','Sporting Goods Shop','Thrift / Vintage Store','Toy / Game Store','Video Store','Warehouse Store',"Women/'s Store"]
    Bar = ['Bar','Beer Bar','Beer Garden','Brewery','Cocktail Bar','Dive Bar','Gastropub','Gay Bar','Irish Pub','Karaoke Bar','Pub','Speakeasy','Sports Bar','Thai Restaurant','Tiki Bar','Whisky Bar','Wine Bar']
    Restaurant = ['Afghan Restaurant','American Restaurant','Arepa Restaurant','Asian Restaurant','BBQ Joint','Belgian Restaurant','Bistro','Brazilian Restaurant','Breakfast Spot','Burger Joint','Burrito Place','Café','Cafeteria','Cajun / Creole Restaurant','Cantonese Restaurant','Caribbean Restaurant','Cheese Shop','Chinese Restaurant','Coffee Shop','Comfort Food Restaurant','Cuban Restaurant','Diner','Dumpling Restaurant','Eastern European Restaurant','Empanada Restaurant','Ethiopian Restaurant','Falafel Restaurant','Fast Food Restaurant','Filipino Restaurant','Fish & Chips Shop','Food Court','Food Service','Food Truck','French Restaurant','Fried Chicken Joint','Frozen Yogurt Shop','German Restaurant','Gluten-free Restaurant','Greek Restaurant','Hot Dog Joint','Ice Cream Shop','Indian Restaurant','Israeli Restaurant','Italian Restaurant','Japanese Restaurant','Juice Bar','Korean Restaurant','Latin American Restaurant','Mediterranean Restaurant','Mexican Restaurant','Middle Eastern Restaurant','New American Restaurant','Noodle House','Peruvian Restaurant','Pizza Place','Poke Place','Portuguese Restaurant','Puerto Rican Restaurant','Ramen Restaurant','Restaurant','Salad Place','Salvadoran Restaurant','Sandwich Place','Scandinavian Restaurant','Seafood Restaurant','South American Restaurant','Southern / Soul Food Restaurant','Spanish Restaurant','Steakhouse','Street Food Gathering','Sushi Restaurant','Taco Place','Tapas Restaurant','Tea Room','Tex-Mex Restaurant','Turkish Restaurant','Vegetarian / Vegan Restaurant','Vietnamese Restaurant','Wings Joint','Xinjiang Restaurant']
    Transportation = ['Bike Rental / Bike Share','Boat or Ferry','Border Crossing','Bridge','Bus Line','Bus Station','Bus Stop','Gas Station','Metro Station','Rental Car Location','Trail','Train Station','Tunnel']
    Entertainment = ['Bowling','Hookah Bar','Lounge','Nightclub','Nightlife Spot','Roof Deck','Event Space']
    Banking = ['ATM','Bank','Check Cashing Service','Credit Union','Banking']
    Culture = ['Art Gallery','Art Museum','Botanical Garden','Comedy Club','Escape Room','Exhibit','Fountain','Garden','General Entertainment','Historic Site','History Museum','Indie Movie Theater','Memorial Site','Monument / Landmark','Movie Theater','Museum','Music Venue','Opera House','Outdoor Sculpture','Park','Pedestrian Plaza','Performing Arts Venue','Planetarium','Plaza','Public Art','Rock Club','Scenic Lookout','Science Museum','Sculpture Garden','Synagogue','Theater','Winery','Zoo Exhibit']

    #Tourism
    Lodging = ['Bed & Breakfast','Hostel','Hotel','Hotel Bar','Hotel Pool']

    #Industrial
    Infrastructure = ['Intersection','Reservoir','River','Road']
    Business = ['Building','Business Service','Construction & Landscaping','Government Building','Insurance Office','Lawyer','Light Rail Station','Office','Post Office']

    cat = cat.replace(to_replace= Grocery, value="Grocery", regex = True)
    cat = cat.replace(to_replace= Health, value="Health", regex = True)
    cat = cat.replace(to_replace= Home, value="Home", regex = True)
    cat = cat.replace(to_replace= Sports, value="Sports", regex = True)

    cat = cat.replace(to_replace= Shopping, value="Shopping", regex = True)
    cat = cat.replace(to_replace= Restaurant, value="Restaurant", regex = True)
    cat = cat.replace(to_replace= Bar, value="Bar", regex = True)
    cat = cat.replace(to_replace= Transportation, value="Transportation", regex = True)
    cat = cat.replace(to_replace= Entertainment, value="Entertainment", regex = True)
    cat = cat.replace(to_replace= Banking, value="Banking", regex = True)
    cat = cat.replace(to_replace= Culture, value="Culture", regex = True)


    cat = cat.replace(to_replace= Lodging, value="Lodging", regex = True)

    cat = cat.replace(to_replace= Infrastructure, value="Infrastructure", regex = True)
    cat = cat.replace(to_replace= Business, value="Business", regex = True)

    #Residential
    cat = cat.replace(regex=r'.*Food.*', value="Grocery")
    cat = cat.replace(regex=r'.*Grocery.*', value="Grocery")


    cat = cat.replace(regex=r'.*Auto.*', value="Home")
    cat = cat.replace(regex=r'.*School.*', value="Home")
    cat = cat.replace(regex=r'.*Residential.*', value="Home")
    cat = cat.replace(regex=r'.*Child.*', value="Home")
    cat = cat.replace(regex=r'.*Care.*', value="Home")
    cat = cat.replace(regex=r'.*Home.*', value="Home")
    cat = cat.replace(regex=r'.*Neighborhood.*', value="Home")

    cat = cat.replace(regex=r'.*Sports.*', value="Sports")
    cat = cat.replace(regex=r'.*Studio.*', value="Sports")
    cat = cat.replace(regex=r'.*Stables.*', value="Sports")
    cat = cat.replace(regex=r'.*Store.*', value="Sports")

    #Residential/Tourism
    cat = cat.replace(regex=r'.*Bar.*', value="Bar")
    cat = cat.replace(regex=r'.*Restaurant.*', value="Restaurant")

    cat = cat.replace(regex=r'.*Men.*', value="Shopping")
    cat = cat.replace(regex=r'.*Women.*', value="Shopping")

    cat = cat.replace(regex=r'.*Culture.*', value="Culture")
    cat = cat.replace(regex=r'.*Event.*', value="Culture")
    cat = cat.replace(regex=r'.*Concert.*', value="Culture")
    cat = cat.replace(regex=r'.*Art.*', value="Culture")

    cat = cat.replace(regex=r'.*Pool.*', value="Entertainment")
    cat = cat.replace(regex=r'.*Entertainment.*', value="Entertainment")


    #Tourism 
    cat = cat.replace(regex=r'.*Tour.*', value="Tourism")
    cat = cat.replace(regex=r'.*Hotel.*', value="Lodging")

    #Industrial 
    cat = cat.replace(regex=r'.*College.*', value="College")
    cat = cat.replace(regex=r'.*Business.*', value="Business")
    cat = cat.replace(regex=r'.*Bank.*', value="Banking")

    cat = cat.replace(regex=r'Grocery|Health|Home|Sports', value="Residential")
    cat = cat.replace(regex=r'Shopping|Bar|Restaurant|Culture|Banking|Entertainment|Transportation', value="RTBoth")
    labels = cat.replace(regex=r'Lodging|Tourism', value="Tourism")
    cat = cat.replace(regex=r'Business|Infrastructure|College|Factory', value="Industrial")

    return labels

# %%
def testprint(x):
    print(x)
    return 0

# neighborhoods_venues_sorted_relabelled = neighborhoods_venues_sorted.apply(lambda x: testprint(x))

# %% [markdown]
# For every neighborhood assign it either Residential, Tourism or Industrial based on majority type of venue

# %%
def countLabels(row):
    r = 0 
    i = 0 
    t = 0 
    o = 0 
    #count how many residential, industrial and tousit establishments there are. 
    for place in row:
        if place == "Residential":
            r += 1
        elif place == "RTBoth":
            #if an establishment is labeled as rtboth it gets a point in both residential and tourist. 
            r += 1
            t += 1
        elif place == "Tourism":
            t += 1
        elif place == "Industrial":
            i += 1
        else:
            o += 1
            #ignore the venue
    
    #neighborhood is assigned label based on majority of establishments. 
    #if tie, break arbitrarly ---> priint these 
    l = {r:"r",i:"i",t:"t"} 
    newLabel = l.get(max(l))
    
    return newLabel

# %%
neighborhoods_venues_sorted_relabelled = neighborhoods_venues_sorted.apply(lambda x: rename_labels(x) if x.name != 'Neighborhood' else x)
# add clustering labels
neighborhoods_venues_sorted_relabelled.insert(0, 'Cluster Labels', 0)
neighborhoods_venues_sorted_relabelled
# Out:
#      Cluster Labels                  Neighborhood 1st Most Common Venue  \
# 0                 0           16th Street Heights                RTBoth
# 1                 0                  Adams Morgan                RTBoth
# 2                 0      American University Park                RTBoth
# 3                 0                     Arboretum                RTBoth
# 4                 0                 Barnaby Woods           Residential
# 5                 0                    Barry Farm                RTBoth
# 6                 0                      Bellevue           Residential
# 7                 0                       Benning                RTBoth
# 8                 0                 Benning Ridge                RTBoth
# 9                 0                  Bloomingdale                RTBoth
# 10                0                     Brentwood                RTBoth
# 11                0                    Brightwood                RTBoth
# 12                0               Brightwood Park                RTBoth
# 13                0                     Brookland           Residential
# 14                0           Burleith/Hillandale           Residential
# 15                0                     Burrville                RTBoth
# 16                0                 Buzzard Point           Residential
# 17                0                  Capitol Hill                RTBoth
# 18                0                  Capitol View                RTBoth
# 19                0                  Cardozo/Shaw                RTBoth
# 20                0                        Carver                RTBoth
# 21                0             Cathedral Heights                RTBoth
# 22                0                    Central NE                RTBoth
# 23                0                   Chevy Chase           Residential
# 24                0                     Chinatown                RTBoth
# 25                0                Cleveland Park                RTBoth
# 26                0              Columbia Heights                RTBoth
# 27                0              Congress Heights           Residential
# 28                0   Connecticut Avenue/K Street               Tourism
# 29                0                     Crestwood        Infrastructure
# 30                0                      Deanwood           Residential
# 31                0                      Douglass                RTBoth
# 32                0                      Downtown               Tourism
# 33                0                 Downtown East               Tourism
# 34                0                 Dupont Circle                RTBoth
# 35                0                   Dupont Park           Residential
# 36                0              Eastland Gardens                RTBoth
# 37                0                     Eckington                RTBoth
# 38                0                      Edgewood           Residential
# 39                0               Fairfax Village                RTBoth
# 40                0                      Fairlawn           Residential
# 41                0                  Foggy Bottom                RTBoth
# 42                0                  Forest Hills           Residential
# 43                0               Fort Davis Park                RTBoth
# 44                0                   Fort Dupont                RTBoth
# 45                0                  Fort Lincoln                RTBoth
# 46                0                   Fort McNair           Residential
# 47                0                  Fort Stanton           Residential
# 48                0                   Fort Totten           Residential
# 49                0             Foxhall Crescents                RTBoth
# 50                0               Foxhall Village                RTBoth
# 51                0            Friendship Heights                RTBoth
# 52                0              Garfield Heights                RTBoth
# 53                0                       Gateway           Residential
# 54                0  George Washington University                RTBoth
# 55                0                    Georgetown                RTBoth
# 56                0          Georgetown Reservoir                RTBoth
# 57                0                   Glover Park                RTBoth
# 58                0                    Grant Park                RTBoth
# 59                0                      Greenway           Residential
# 60                0                     Hawthorne              Business
# 61                0                     Hill East                RTBoth
# 62                0                     Hillcrest                RTBoth
# 63                0                     Hillsdale           Residential
# 64                0            Historic Anacostia                RTBoth
# 65                0             Howard University                RTBoth
# 66                0                      Ivy City               Tourism
# 67                0              Kalorama Heights                RTBoth
# 68                0                    Kenilworth                RTBoth
# 69                0                  Kingman Park                RTBoth
# 70                0         Knox Hill/Buena Vista           Residential
# 71                0                  Lamond Riggs           Residential
# 72                0                       Langdon                RTBoth
# 73                0                      Langston                RTBoth
# 74                0                Lanier Heights                RTBoth
# 75                0                 Le Droit Park                RTBoth
# 76                0               Lincoln Heights           Residential
# 77                0                  Lincoln Park                RTBoth
# 78                0             Logan Circle/Shaw                RTBoth
# 79                0                    Manor Park                RTBoth
# 80                0              Marshall Heights           Residential
# 81                0            Mass. Ave. Heights               Tourism
# 82                0                       Mayfair                RTBoth
# 83                0                McLean Gardens                RTBoth
# 84                0                 Michigan Park           Residential
# 85                0               Monumental Core                RTBoth
# 86                0                Mount Pleasant                RTBoth
# 87                0           Mount Vernon Square               Tourism
# 88                0         Mount Vernon Triangle           Residential
# 89                0                   NE Boundary           Residential
# 90                0                     Navy Yard                RTBoth
# 91                0                Naylor Gardens           Residential
# 92                0                Near Northeast                RTBoth
# 93                0                Near Southeast           Residential
# 94                0          North Capitol Street                RTBoth
# 95                0          North Cleveland Park                RTBoth
# 96                0           North Michigan Park           Residential
# 97                0                     Palisades                RTBoth
# 98                0                     Park View                RTBoth
# 99                0                   Penn Branch                RTBoth
# 100               0                  Penn Quarter                RTBoth
# 101               0                      Petworth                RTBoth
# 102               0                 Pleasant Hill                RTBoth
# 103               0               Pleasant Plains                RTBoth
# 104               0                 Queens Chapel           Residential
# 105               0              Randle Highlands        Infrastructure
# 106               0                 River Terrace           Residential
# 107               0                 Shepherd Park           Residential
# 108               0                       Shipley           Residential
# 109               0                       Skyland                RTBoth
# 110               0                 South Central        Infrastructure
# 111               0     Southwest Employment Area                RTBoth
# 112               0          Southwest/Waterfront                RTBoth
# 113               0                 Spring Valley           Residential
# 114               0                  Stanton Park           Residential
# 115               0                    Stronghold           Residential
# 116               0                        Takoma                RTBoth
# 117               0                    Tenleytown                RTBoth
# 118               0                      Trinidad           Residential
# 119               0                Truxton Circle                RTBoth
# 120               0                       Twining           Residential
# 121               0            University Heights                RTBoth
# 122               0                      Van Ness                RTBoth
# 123               0          Washington Highlands           Residential
# 124               0                Wesley Heights                RTBoth
# 125               0                      West End               Tourism
# 126               0                      Woodland           Residential
# 127               0          Woodland-Normanstone                RTBoth
# 128               0                  Woodley Park                RTBoth
# 129               0                     Woodridge           Residential
#
#     2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                  RTBoth                RTBoth                RTBoth
# 1                  RTBoth                RTBoth                RTBoth
# 2                  RTBoth           Residential                RTBoth
# 3                  RTBoth                RTBoth           Residential
# 4             Residential                RTBoth                RTBoth
# 5             Residential        Infrastructure                RTBoth
# 6             Residential           Residential                RTBoth
# 7             Residential                RTBoth                RTBoth
# 8                Business           Residential                RTBoth
# 9             Residential           Residential           Residential
# 10                 RTBoth                RTBoth                RTBoth
# 11                 RTBoth                RTBoth                RTBoth
# 12                 RTBoth                RTBoth           Residential
# 13                 RTBoth                RTBoth                RTBoth
# 14                 RTBoth           Residential           Residential
# 15            Residential           Residential                RTBoth
# 16                 RTBoth           Residential                RTBoth
# 17                 RTBoth           Residential                RTBoth
# 18               Business           Residential           Residential
# 19                 RTBoth                RTBoth                RTBoth
# 20            Residential           Residential                RTBoth
# 21                 RTBoth           Residential           Residential
# 22                 RTBoth                RTBoth                RTBoth
# 23            Residential           Residential           Residential
# 24                 RTBoth               Tourism                RTBoth
# 25                 RTBoth                RTBoth           Residential
# 26            Residential                RTBoth           Residential
# 27                 RTBoth           Residential           Residential
# 28                 RTBoth                RTBoth                RTBoth
# 29            Residential                RTBoth                RTBoth
# 30            Residential                RTBoth           Residential
# 31                 RTBoth           Residential                RTBoth
# 32                 RTBoth                RTBoth                RTBoth
# 33                 RTBoth           Residential                RTBoth
# 34                 RTBoth                RTBoth           Residential
# 35         Infrastructure                RTBoth           Residential
# 36            Residential                RTBoth                RTBoth
# 37                 RTBoth                RTBoth           Residential
# 38                 RTBoth           Residential                RTBoth
# 39               Business                RTBoth           Residential
# 40            Residential                RTBoth           Residential
# 41                 RTBoth               Tourism                RTBoth
# 42                 RTBoth                RTBoth                RTBoth
# 43                 RTBoth                RTBoth                RTBoth
# 44            Residential           Residential           Residential
# 45                 RTBoth                RTBoth                RTBoth
# 46                 RTBoth           Residential           Residential
# 47         Infrastructure                RTBoth                RTBoth
# 48                 RTBoth                RTBoth           Residential
# 49                College           Residential                RTBoth
# 50                 RTBoth                RTBoth           Residential
# 51                 RTBoth                RTBoth                RTBoth
# 52                 RTBoth           Residential                RTBoth
# 53                 RTBoth           Residential                RTBoth
# 54                Tourism                RTBoth                RTBoth
# 55                 RTBoth                RTBoth                RTBoth
# 56            Residential                RTBoth           Residential
# 57            Residential                RTBoth                RTBoth
# 58                 RTBoth           Residential                RTBoth
# 59            Residential                RTBoth                RTBoth
# 60               Business                RTBoth                RTBoth
# 61            Residential           Residential                RTBoth
# 62            Residential        Infrastructure                RTBoth
# 63            Residential           Residential                RTBoth
# 64                 RTBoth           Residential                RTBoth
# 65                 RTBoth                RTBoth           Residential
# 66                 RTBoth                RTBoth                RTBoth
# 67                 RTBoth           Residential                RTBoth
# 68                 RTBoth                RTBoth                RTBoth
# 69         Infrastructure           Residential                RTBoth
# 70            Residential           Residential           Residential
# 71            Residential                RTBoth                RTBoth
# 72                 RTBoth                RTBoth           Residential
# 73               Business           Residential                RTBoth
# 74                 RTBoth                RTBoth                RTBoth
# 75            Residential                RTBoth                RTBoth
# 76                Factory                RTBoth                RTBoth
# 77                 RTBoth                RTBoth                RTBoth
# 78                 RTBoth                RTBoth           Residential
# 79            Residential                RTBoth           Residential
# 80               Business               Tourism                RTBoth
# 81                 RTBoth                RTBoth                RTBoth
# 82                 RTBoth           Residential                RTBoth
# 83                 RTBoth           Residential                RTBoth
# 84                 RTBoth                RTBoth           Residential
# 85                 RTBoth                RTBoth                RTBoth
# 86                 RTBoth                RTBoth           Residential
# 87                 RTBoth                RTBoth                RTBoth
# 88                 RTBoth                RTBoth                RTBoth
# 89                 RTBoth                RTBoth                RTBoth
# 90                 RTBoth                RTBoth                RTBoth
# 91            Residential                RTBoth                RTBoth
# 92            Residential                RTBoth                RTBoth
# 93                 RTBoth                RTBoth                RTBoth
# 94            Residential                RTBoth                RTBoth
# 95            Residential                RTBoth                RTBoth
# 96                 RTBoth                RTBoth           Residential
# 97            Residential           Residential              Business
# 98                 RTBoth                RTBoth           Residential
# 99                 RTBoth           Residential           Residential
# 100                RTBoth                RTBoth                RTBoth
# 101                RTBoth                RTBoth           Residential
# 102                RTBoth           Residential           Residential
# 103                RTBoth                RTBoth           Residential
# 104                RTBoth           Residential           Residential
# 105           Residential                RTBoth                RTBoth
# 106                RTBoth                RTBoth                RTBoth
# 107                RTBoth                RTBoth                RTBoth
# 108                RTBoth           Residential                RTBoth
# 109                RTBoth        Infrastructure                RTBoth
# 110           Residential           Residential                RTBoth
# 111                RTBoth                RTBoth                RTBoth
# 112                RTBoth           Residential                RTBoth
# 113           Residential           Residential                RTBoth
# 114           Residential                RTBoth                RTBoth
# 115                RTBoth                RTBoth           Residential
# 116                RTBoth                RTBoth           Residential
# 117           Residential                RTBoth           Residential
# 118                RTBoth                RTBoth                RTBoth
# 119           Residential           Residential                RTBoth
# 120                RTBoth           Residential                RTBoth
# 121                RTBoth           Residential           Residential
# 122                RTBoth           Residential                RTBoth
# 123           Residential           Residential                RTBoth
# 124                RTBoth           Residential                RTBoth
# 125                RTBoth                RTBoth           Residential
# 126                RTBoth                RTBoth               Tourism
# 127                RTBoth           Residential                RTBoth
# 128           Residential                RTBoth                RTBoth
# 129                RTBoth                RTBoth                RTBoth
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0                  RTBoth                RTBoth               Tourism
# 1             Residential                RTBoth                RTBoth
# 2                  RTBoth               Factory                RTBoth
# 3                  RTBoth                RTBoth                RTBoth
# 4                  RTBoth                RTBoth               Factory
# 5                  RTBoth                RTBoth                RTBoth
# 6             Residential           Residential                RTBoth
# 7             Residential           Residential                RTBoth
# 8             Residential                RTBoth                RTBoth
# 9             Residential                RTBoth                RTBoth
# 10                 RTBoth           Residential                RTBoth
# 11            Residential                RTBoth                RTBoth
# 12                 RTBoth           Residential                RTBoth
# 13                Factory                RTBoth           Residential
# 14            Residential                RTBoth               Factory
# 15                 RTBoth           Residential                RTBoth
# 16                 RTBoth           Residential           Residential
# 17                 RTBoth           Residential           Residential
# 18                 RTBoth                RTBoth                RTBoth
# 19            Residential           Residential                RTBoth
# 20                 RTBoth           Residential              Business
# 21            Residential           Residential                RTBoth
# 22                 RTBoth                RTBoth                RTBoth
# 23                 RTBoth                RTBoth                RTBoth
# 24                 RTBoth                RTBoth                RTBoth
# 25                 RTBoth                RTBoth                RTBoth
# 26            Residential                RTBoth                RTBoth
# 27         Infrastructure           Residential                RTBoth
# 28                 RTBoth                RTBoth                RTBoth
# 29                 RTBoth               Factory                RTBoth
# 30                 RTBoth                RTBoth               Factory
# 31                 RTBoth           Residential                RTBoth
# 32                 RTBoth                RTBoth                RTBoth
# 33            Residential                RTBoth                RTBoth
# 34                 RTBoth                RTBoth           Residential
# 35                 RTBoth                RTBoth                RTBoth
# 36                 RTBoth               Factory                RTBoth
# 37            Residential                RTBoth               Factory
# 38            Residential                RTBoth                RTBoth
# 39                 RTBoth                RTBoth                RTBoth
# 40            Residential                RTBoth                RTBoth
# 41                 RTBoth                RTBoth                RTBoth
# 42                 RTBoth                RTBoth           Residential
# 43            Residential                RTBoth               Factory
# 44            Residential           Residential                RTBoth
# 45                 RTBoth           Residential                RTBoth
# 46            Residential                RTBoth           Residential
# 47            Residential                RTBoth                RTBoth
# 48                 RTBoth                RTBoth                RTBoth
# 49            Residential                RTBoth                RTBoth
# 50                 RTBoth           Residential           Residential
# 51                 RTBoth           Residential           Residential
# 52            Residential                RTBoth                RTBoth
# 53                 RTBoth              Business                RTBoth
# 54                 RTBoth                RTBoth           Residential
# 55                 RTBoth                RTBoth           Residential
# 56            Residential                RTBoth                RTBoth
# 57                 RTBoth                RTBoth           Residential
# 58                 RTBoth               Factory                RTBoth
# 59                Factory                RTBoth           Residential
# 60            Residential                RTBoth                RTBoth
# 61                 RTBoth               Factory                RTBoth
# 62            Residential           Residential                RTBoth
# 63                 RTBoth           Residential                RTBoth
# 64                 RTBoth                RTBoth           Residential
# 65                 RTBoth                RTBoth                RTBoth
# 66                 RTBoth                RTBoth                RTBoth
# 67                 RTBoth                RTBoth                RTBoth
# 68            Residential           Residential                RTBoth
# 69                 RTBoth           Residential                RTBoth
# 70                 RTBoth                RTBoth               Factory
# 71                 RTBoth                RTBoth           Residential
# 72            Residential               Factory                RTBoth
# 73            Residential                RTBoth           Residential
# 74                 RTBoth           Residential                RTBoth
# 75                 RTBoth                RTBoth                RTBoth
# 76            Residential           Residential                RTBoth
# 77                 RTBoth           Residential                RTBoth
# 78                 RTBoth                RTBoth                RTBoth
# 79                 RTBoth           Residential                RTBoth
# 80                Factory                RTBoth           Residential
# 81                 RTBoth                RTBoth                RTBoth
# 82                 RTBoth               Factory                RTBoth
# 83            Residential           Residential                RTBoth
# 84                 RTBoth                RTBoth               Factory
# 85                 RTBoth           Residential                RTBoth
# 86                 RTBoth           Residential                RTBoth
# 87                 RTBoth                RTBoth                RTBoth
# 88                Tourism                RTBoth           Residential
# 89                Factory                RTBoth           Residential
# 90                 RTBoth                RTBoth                RTBoth
# 91                 RTBoth                RTBoth           Residential
# 92                 RTBoth                RTBoth           Residential
# 93            Residential                RTBoth                RTBoth
# 94                 RTBoth                RTBoth                RTBoth
# 95                 RTBoth                RTBoth               Factory
# 96                 RTBoth                RTBoth                RTBoth
# 97                 RTBoth                RTBoth                RTBoth
# 98            Residential                RTBoth                RTBoth
# 99                 RTBoth           Residential                RTBoth
# 100                RTBoth                RTBoth           Residential
# 101           Residential                RTBoth                RTBoth
# 102           Residential                RTBoth           Residential
# 103                RTBoth           Residential           Residential
# 104           Residential                RTBoth                RTBoth
# 105                RTBoth           Residential                RTBoth
# 106                RTBoth                RTBoth           Residential
# 107                RTBoth                RTBoth               Factory
# 108           Residential                RTBoth                RTBoth
# 109                RTBoth                RTBoth           Residential
# 110           Residential           Residential           Residential
# 111                RTBoth               Tourism                RTBoth
# 112           Residential                RTBoth           Residential
# 113                RTBoth               Factory                RTBoth
# 114           Residential           Residential                RTBoth
# 115                RTBoth                RTBoth                RTBoth
# 116           Residential                RTBoth                RTBoth
# 117           Residential                RTBoth                RTBoth
# 118           Residential               Factory                RTBoth
# 119                RTBoth                RTBoth                RTBoth
# 120           Residential           Residential                RTBoth
# 121                RTBoth           Residential                RTBoth
# 122                RTBoth                RTBoth                RTBoth
# 123                RTBoth           Residential                RTBoth
# 124        Infrastructure                RTBoth                RTBoth
# 125                RTBoth                RTBoth                RTBoth
# 126                RTBoth                RTBoth           Residential
# 127                RTBoth           Residential                RTBoth
# 128               Tourism                RTBoth           Residential
# 129           Residential                RTBoth                RTBoth
#
#     8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0                  RTBoth           Residential            Residential
# 1                  RTBoth                RTBoth                 RTBoth
# 2             Residential                RTBoth            Residential
# 3             Residential                RTBoth                 RTBoth
# 4                  RTBoth           Residential                 RTBoth
# 5                 Factory                RTBoth            Residential
# 6                  RTBoth                RTBoth                 RTBoth
# 7                  RTBoth                RTBoth            Residential
# 8                  RTBoth               Factory                 RTBoth
# 9             Residential                RTBoth                 RTBoth
# 10            Residential           Residential                 RTBoth
# 11                 RTBoth                RTBoth                 RTBoth
# 12                 RTBoth                RTBoth            Residential
# 13                 RTBoth           Residential                 RTBoth
# 14                 RTBoth           Residential                 RTBoth
# 15                 RTBoth                RTBoth                Factory
# 16                 RTBoth           Residential                 RTBoth
# 17                 RTBoth                RTBoth                 RTBoth
# 18                Factory                RTBoth            Residential
# 19                 RTBoth                RTBoth                 RTBoth
# 20                 RTBoth                RTBoth                 RTBoth
# 21            Residential           Residential                 RTBoth
# 22                 RTBoth           Residential            Residential
# 23                 RTBoth               Factory                 RTBoth
# 24                 RTBoth                RTBoth                 RTBoth
# 25                 RTBoth                RTBoth                 RTBoth
# 26            Residential                RTBoth                 RTBoth
# 27         Infrastructure                RTBoth                Tourism
# 28            Residential                RTBoth                 RTBoth
# 29            Residential                RTBoth            Residential
# 30                 RTBoth           Residential                 RTBoth
# 31                 RTBoth           Residential                 RTBoth
# 32                 RTBoth                RTBoth                 RTBoth
# 33                 RTBoth                RTBoth                 RTBoth
# 34                 RTBoth                RTBoth                 RTBoth
# 35            Residential                RTBoth            Residential
# 36            Residential           Residential                 RTBoth
# 37                 RTBoth           Residential                 RTBoth
# 38                 RTBoth           Residential            Residential
# 39                 RTBoth                RTBoth                Factory
# 40                Factory                RTBoth            Residential
# 41                 RTBoth                RTBoth                 RTBoth
# 42                 RTBoth           Residential                 RTBoth
# 43                 RTBoth           Residential                 RTBoth
# 44                Factory                RTBoth            Residential
# 45                 RTBoth                RTBoth                 RTBoth
# 46            Residential                RTBoth                 RTBoth
# 47                Factory                RTBoth            Residential
# 48                Factory                RTBoth            Residential
# 49                 RTBoth           Residential                 RTBoth
# 50                 RTBoth                RTBoth                Factory
# 51                 RTBoth               Tourism                 RTBoth
# 52                Factory                RTBoth            Residential
# 53            Residential                RTBoth                 RTBoth
# 54                 RTBoth               College            Residential
# 55                 RTBoth                RTBoth            Residential
# 56                 RTBoth               Factory                 RTBoth
# 57                 RTBoth                RTBoth            Residential
# 58            Residential                RTBoth            Residential
# 59                 RTBoth           Residential                 RTBoth
# 60                Factory                RTBoth            Residential
# 61            Residential                RTBoth            Residential
# 62                 RTBoth                RTBoth                Factory
# 63                 RTBoth               Factory                 RTBoth
# 64                 RTBoth                RTBoth                 RTBoth
# 65                 RTBoth                RTBoth            Residential
# 66                 RTBoth               Factory                 RTBoth
# 67                 RTBoth                RTBoth                 RTBoth
# 68                Factory                RTBoth            Residential
# 69                 RTBoth               Factory                 RTBoth
# 70                 RTBoth           Residential                 RTBoth
# 71            Residential              Business                 RTBoth
# 72            Residential                RTBoth            Residential
# 73            Residential                RTBoth            Residential
# 74                 RTBoth                RTBoth                 RTBoth
# 75                 RTBoth                RTBoth                 RTBoth
# 76                 RTBoth                RTBoth            Residential
# 77            Residential                RTBoth                 RTBoth
# 78            Residential                RTBoth                 RTBoth
# 79                 RTBoth               Factory                 RTBoth
# 80                 RTBoth           Residential                 RTBoth
# 81            Residential           Residential            Residential
# 82            Residential                RTBoth            Residential
# 83                 RTBoth                RTBoth                 RTBoth
# 84                 RTBoth           Residential                 RTBoth
# 85            Residential                RTBoth                 RTBoth
# 86                 RTBoth                RTBoth                 RTBoth
# 87                 RTBoth           Residential            Residential
# 88                 RTBoth               College                 RTBoth
# 89                 RTBoth           Residential            Residential
# 90            Residential                RTBoth                 RTBoth
# 91            Residential                RTBoth            Residential
# 92            Residential                RTBoth                 RTBoth
# 93            Residential                RTBoth                 RTBoth
# 94                 RTBoth              Business                 RTBoth
# 95                 RTBoth           Residential                 RTBoth
# 96                Factory                RTBoth            Residential
# 97            Residential                RTBoth         Infrastructure
# 98                 RTBoth                RTBoth                 RTBoth
# 99                Factory                RTBoth            Residential
# 100                RTBoth                RTBoth                 RTBoth
# 101                RTBoth                RTBoth                 RTBoth
# 102                RTBoth                RTBoth                 RTBoth
# 103                RTBoth                RTBoth                 RTBoth
# 104                RTBoth                RTBoth                Factory
# 105                RTBoth                RTBoth                 RTBoth
# 106                RTBoth           Residential                 RTBoth
# 107                RTBoth           Residential            Residential
# 108                RTBoth                RTBoth                 RTBoth
# 109           Residential                RTBoth                Factory
# 110                RTBoth               Factory                 RTBoth
# 111           Residential                RTBoth                 RTBoth
# 112                RTBoth                RTBoth                 RTBoth
# 113           Residential                RTBoth            Residential
# 114                RTBoth                RTBoth                Factory
# 115               Factory           Residential                 RTBoth
# 116                RTBoth           Residential            Residential
# 117                RTBoth                RTBoth                 RTBoth
# 118           Residential                RTBoth            Residential
# 119           Residential                RTBoth                 RTBoth
# 120                RTBoth                RTBoth                Factory
# 121                RTBoth                RTBoth                 RTBoth
# 122                RTBoth           Residential                 RTBoth
# 123           Residential                RTBoth                 RTBoth
# 124                RTBoth           Residential            Residential
# 125           Residential                RTBoth         Infrastructure
# 126           Residential                RTBoth                 RTBoth
# 127                RTBoth                RTBoth                 RTBoth
# 128               Tourism           Residential            Residential
# 129               Factory                RTBoth            Residential

# %% [markdown]
# Run algorithm assigning weights for each neighorhood

# %%
# for each neighborhood 
#     count how many residential, industrial and tousit establishments there are. 
for index, row in neighborhoods_venues_sorted_relabelled.iterrows():
    newLabel = countLabels(row)
    print(f'Index: {index}, newLabel: {newLabel}, row: {row.values}\n')
    # cluster neighborhoods based on labels
    neighborhoods_venues_sorted_relabelled['Cluster Labels'] = newLabel
# Out:
# Index: 0, newLabel: r, row: [0 '16th Street Heights' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth'
#  'RTBoth' 'Tourism' 'RTBoth' 'Residential' 'Residential']
#
# Index: 1, newLabel: r, row: [0 'Adams Morgan' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential'
#  'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 2, newLabel: r, row: [0 'American University Park' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth'
#  'RTBoth' 'Factory' 'RTBoth' 'Residential' 'RTBoth' 'Residential']
#
# Index: 3, newLabel: r, row: [0 'Arboretum' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth'
#  'RTBoth' 'Residential' 'RTBoth' 'RTBoth']
#
# Index: 4, newLabel: r, row: [0 'Barnaby Woods' 'Residential' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth'
#  'RTBoth' 'Factory' 'RTBoth' 'Residential' 'RTBoth']
#
# Index: 5, newLabel: r, row: [0 'Barry Farm' 'RTBoth' 'Residential' 'Infrastructure' 'RTBoth' 'RTBoth'
#  'RTBoth' 'RTBoth' 'Factory' 'RTBoth' 'Residential']
#
# Index: 6, newLabel: r, row: [0 'Bellevue' 'Residential' 'Residential' 'Residential' 'RTBoth'
#  'Residential' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 7, newLabel: r, row: [0 'Benning' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth' 'Residential'
#  'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential']
#
# Index: 8, newLabel: r, row: [0 'Benning Ridge' 'RTBoth' 'Business' 'Residential' 'RTBoth'
#  'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'Factory' 'RTBoth']
#
# Index: 9, newLabel: r, row: [0 'Bloomingdale' 'RTBoth' 'Residential' 'Residential' 'Residential'
#  'Residential' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth']
#
# Index: 10, newLabel: r, row: [0 'Brentwood' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential'
#  'RTBoth' 'Residential' 'Residential' 'RTBoth']
#
# Index: 11, newLabel: r, row: [0 'Brightwood' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth'
#  'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 12, newLabel: r, row: [0 'Brightwood Park' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth'
#  'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential']
#
# Index: 13, newLabel: r, row: [0 'Brookland' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'Factory' 'RTBoth'
#  'Residential' 'RTBoth' 'Residential' 'RTBoth']
#
# Index: 14, newLabel: r, row: [0 'Burleith/Hillandale' 'Residential' 'RTBoth' 'Residential'
#  'Residential' 'Residential' 'RTBoth' 'Factory' 'RTBoth' 'Residential'
#  'RTBoth']
#
# Index: 15, newLabel: r, row: [0 'Burrville' 'RTBoth' 'Residential' 'Residential' 'RTBoth' 'RTBoth'
#  'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'Factory']
#
# Index: 16, newLabel: r, row: [0 'Buzzard Point' 'Residential' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth'
#  'Residential' 'Residential' 'RTBoth' 'Residential' 'RTBoth']
#
# Index: 17, newLabel: r, row: [0 'Capitol Hill' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth'
#  'Residential' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 18, newLabel: r, row: [0 'Capitol View' 'RTBoth' 'Business' 'Residential' 'Residential' 'RTBoth'
#  'RTBoth' 'RTBoth' 'Factory' 'RTBoth' 'Residential']
#
# Index: 19, newLabel: r, row: [0 'Cardozo/Shaw' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential'
#  'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 20, newLabel: r, row: [0 'Carver' 'RTBoth' 'Residential' 'Residential' 'RTBoth' 'RTBoth'
#  'Residential' 'Business' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 21, newLabel: r, row: [0 'Cathedral Heights' 'RTBoth' 'RTBoth' 'Residential' 'Residential'
#  'Residential' 'Residential' 'RTBoth' 'Residential' 'Residential' 'RTBoth']
#
# Index: 22, newLabel: r, row: [0 'Central NE' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth'
#  'RTBoth' 'RTBoth' 'Residential' 'Residential']
#
# Index: 23, newLabel: r, row: [0 'Chevy Chase' 'Residential' 'Residential' 'Residential' 'Residential'
#  'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'Factory' 'RTBoth']
#
# Index: 24, newLabel: t, row: [0 'Chinatown' 'RTBoth' 'RTBoth' 'Tourism' 'RTBoth' 'RTBoth' 'RTBoth'
#  'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 25, newLabel: r, row: [0 'Cleveland Park' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth'
#  'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 26, newLabel: r, row: [0 'Columbia Heights' 'RTBoth' 'Residential' 'RTBoth' 'Residential'
#  'Residential' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth']
#
# Index: 27, newLabel: r, row: [0 'Congress Heights' 'Residential' 'RTBoth' 'Residential' 'Residential'
#  'Infrastructure' 'Residential' 'RTBoth' 'Infrastructure' 'RTBoth'
#  'Tourism']
#
# Index: 28, newLabel: t, row: [0 'Connecticut Avenue/K Street' 'Tourism' 'RTBoth' 'RTBoth' 'RTBoth'
#  'RTBoth' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth']
#
# Index: 29, newLabel: r, row: [0 'Crestwood' 'Infrastructure' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth'
#  'Factory' 'RTBoth' 'Residential' 'RTBoth' 'Residential']
#
# Index: 30, newLabel: r, row: [0 'Deanwood' 'Residential' 'Residential' 'RTBoth' 'Residential' 'RTBoth'
#  'RTBoth' 'Factory' 'RTBoth' 'Residential' 'RTBoth']
#
# Index: 31, newLabel: r, row: [0 'Douglass' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth'
#  'Residential' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth']
#
# Index: 32, newLabel: t, row: [0 'Downtown' 'Tourism' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth'
#  'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 33, newLabel: r, row: [0 'Downtown East' 'Tourism' 'RTBoth' 'Residential' 'RTBoth' 'Residential'
#  'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 34, newLabel: r, row: [0 'Dupont Circle' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth'
#  'RTBoth' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 35, newLabel: r, row: [0 'Dupont Park' 'Residential' 'Infrastructure' 'RTBoth' 'Residential'
#  'RTBoth' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth' 'Residential']
#
# Index: 36, newLabel: r, row: [0 'Eastland Gardens' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth'
#  'Factory' 'RTBoth' 'Residential' 'Residential' 'RTBoth']
#
# Index: 37, newLabel: r, row: [0 'Eckington' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential' 'Residential'
#  'RTBoth' 'Factory' 'RTBoth' 'Residential' 'RTBoth']
#
# Index: 38, newLabel: r, row: [0 'Edgewood' 'Residential' 'RTBoth' 'Residential' 'RTBoth' 'Residential'
#  'RTBoth' 'RTBoth' 'RTBoth' 'Residential' 'Residential']
#
# Index: 39, newLabel: r, row: [0 'Fairfax Village' 'RTBoth' 'Business' 'RTBoth' 'Residential' 'RTBoth'
#  'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'Factory']
#
# Index: 40, newLabel: r, row: [0 'Fairlawn' 'Residential' 'Residential' 'RTBoth' 'Residential'
#  'Residential' 'RTBoth' 'RTBoth' 'Factory' 'RTBoth' 'Residential']
#
# Index: 41, newLabel: t, row: [0 'Foggy Bottom' 'RTBoth' 'RTBoth' 'Tourism' 'RTBoth' 'RTBoth' 'RTBoth'
#  'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 42, newLabel: r, row: [0 'Forest Hills' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth'
#  'RTBoth' 'Residential' 'RTBoth' 'Residential' 'RTBoth']
#
# Index: 43, newLabel: r, row: [0 'Fort Davis Park' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential'
#  'RTBoth' 'Factory' 'RTBoth' 'Residential' 'RTBoth']
#
# Index: 44, newLabel: r, row: [0 'Fort Dupont' 'RTBoth' 'Residential' 'Residential' 'Residential'
#  'Residential' 'Residential' 'RTBoth' 'Factory' 'RTBoth' 'Residential']
#
# Index: 45, newLabel: r, row: [0 'Fort Lincoln' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth'
#  'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 46, newLabel: r, row: [0 'Fort McNair' 'Residential' 'RTBoth' 'Residential' 'Residential'
#  'Residential' 'RTBoth' 'Residential' 'Residential' 'RTBoth' 'RTBoth']
#
# Index: 47, newLabel: r, row: [0 'Fort Stanton' 'Residential' 'Infrastructure' 'RTBoth' 'RTBoth'
#  'Residential' 'RTBoth' 'RTBoth' 'Factory' 'RTBoth' 'Residential']
#
# Index: 48, newLabel: r, row: [0 'Fort Totten' 'Residential' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth'
#  'RTBoth' 'RTBoth' 'Factory' 'RTBoth' 'Residential']
#
# Index: 49, newLabel: r, row: [0 'Foxhall Crescents' 'RTBoth' 'College' 'Residential' 'RTBoth'
#  'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth']
#
# Index: 50, newLabel: r, row: [0 'Foxhall Village' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth'
#  'Residential' 'Residential' 'RTBoth' 'RTBoth' 'Factory']
#
# Index: 51, newLabel: r, row: [0 'Friendship Heights' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth'
#  'Residential' 'Residential' 'RTBoth' 'Tourism' 'RTBoth']
#
# Index: 52, newLabel: r, row: [0 'Garfield Heights' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth'
#  'Residential' 'RTBoth' 'RTBoth' 'Factory' 'RTBoth' 'Residential']
#
# Index: 53, newLabel: r, row: [0 'Gateway' 'Residential' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth'
#  'Business' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth']
#
# Index: 54, newLabel: r, row: [0 'George Washington University' 'RTBoth' 'Tourism' 'RTBoth' 'RTBoth'
#  'RTBoth' 'RTBoth' 'Residential' 'RTBoth' 'College' 'Residential']
#
# Index: 55, newLabel: r, row: [0 'Georgetown' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth'
#  'Residential' 'RTBoth' 'RTBoth' 'Residential']
#
# Index: 56, newLabel: r, row: [0 'Georgetown Reservoir' 'RTBoth' 'Residential' 'RTBoth' 'Residential'
#  'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'Factory' 'RTBoth']
#
# Index: 57, newLabel: r, row: [0 'Glover Park' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth'
#  'RTBoth' 'Residential' 'RTBoth' 'RTBoth' 'Residential']
#
# Index: 58, newLabel: r, row: [0 'Grant Park' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth'
#  'Factory' 'RTBoth' 'Residential' 'RTBoth' 'Residential']
#
# Index: 59, newLabel: r, row: [0 'Greenway' 'Residential' 'Residential' 'RTBoth' 'RTBoth' 'Factory'
#  'RTBoth' 'Residential' 'RTBoth' 'Residential' 'RTBoth']
#
# Index: 60, newLabel: r, row: [0 'Hawthorne' 'Business' 'Business' 'RTBoth' 'RTBoth' 'Residential'
#  'RTBoth' 'RTBoth' 'Factory' 'RTBoth' 'Residential']
#
# Index: 61, newLabel: r, row: [0 'Hill East' 'RTBoth' 'Residential' 'Residential' 'RTBoth' 'RTBoth'
#  'Factory' 'RTBoth' 'Residential' 'RTBoth' 'Residential']
#
# Index: 62, newLabel: r, row: [0 'Hillcrest' 'RTBoth' 'Residential' 'Infrastructure' 'RTBoth'
#  'Residential' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'Factory']
#
# Index: 63, newLabel: r, row: [0 'Hillsdale' 'Residential' 'Residential' 'Residential' 'RTBoth' 'RTBoth'
#  'Residential' 'RTBoth' 'RTBoth' 'Factory' 'RTBoth']
#
# Index: 64, newLabel: r, row: [0 'Historic Anacostia' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth'
#  'RTBoth' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 65, newLabel: r, row: [0 'Howard University' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth'
#  'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential']
#
# Index: 66, newLabel: t, row: [0 'Ivy City' 'Tourism' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth'
#  'RTBoth' 'RTBoth' 'Factory' 'RTBoth']
#
# Index: 67, newLabel: r, row: [0 'Kalorama Heights' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth'
#  'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 68, newLabel: r, row: [0 'Kenilworth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential'
#  'Residential' 'RTBoth' 'Factory' 'RTBoth' 'Residential']
#
# Index: 69, newLabel: r, row: [0 'Kingman Park' 'RTBoth' 'Infrastructure' 'Residential' 'RTBoth'
#  'RTBoth' 'Residential' 'RTBoth' 'RTBoth' 'Factory' 'RTBoth']
#
# Index: 70, newLabel: r, row: [0 'Knox Hill/Buena Vista' 'Residential' 'Residential' 'Residential'
#  'Residential' 'RTBoth' 'RTBoth' 'Factory' 'RTBoth' 'Residential' 'RTBoth']
#
# Index: 71, newLabel: r, row: [0 'Lamond Riggs' 'Residential' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth'
#  'RTBoth' 'Residential' 'Residential' 'Business' 'RTBoth']
#
# Index: 72, newLabel: r, row: [0 'Langdon' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential' 'Residential'
#  'Factory' 'RTBoth' 'Residential' 'RTBoth' 'Residential']
#
# Index: 73, newLabel: r, row: [0 'Langston' 'RTBoth' 'Business' 'Residential' 'RTBoth' 'Residential'
#  'RTBoth' 'Residential' 'Residential' 'RTBoth' 'Residential']
#
# Index: 74, newLabel: r, row: [0 'Lanier Heights' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth'
#  'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 75, newLabel: r, row: [0 'Le Droit Park' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth'
#  'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 76, newLabel: r, row: [0 'Lincoln Heights' 'Residential' 'Factory' 'RTBoth' 'RTBoth'
#  'Residential' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential']
#
# Index: 77, newLabel: r, row: [0 'Lincoln Park' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth'
#  'Residential' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth']
#
# Index: 78, newLabel: r, row: [0 'Logan Circle/Shaw' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth'
#  'RTBoth' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth']
#
# Index: 79, newLabel: r, row: [0 'Manor Park' 'RTBoth' 'Residential' 'RTBoth' 'Residential' 'RTBoth'
#  'Residential' 'RTBoth' 'RTBoth' 'Factory' 'RTBoth']
#
# Index: 80, newLabel: r, row: [0 'Marshall Heights' 'Residential' 'Business' 'Tourism' 'RTBoth'
#  'Factory' 'RTBoth' 'Residential' 'RTBoth' 'Residential' 'RTBoth']
#
# Index: 81, newLabel: r, row: [0 'Mass. Ave. Heights' 'Tourism' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth'
#  'RTBoth' 'RTBoth' 'Residential' 'Residential' 'Residential']
#
# Index: 82, newLabel: r, row: [0 'Mayfair' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth' 'Factory'
#  'RTBoth' 'Residential' 'RTBoth' 'Residential']
#
# Index: 83, newLabel: r, row: [0 'McLean Gardens' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth' 'Residential'
#  'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 84, newLabel: r, row: [0 'Michigan Park' 'Residential' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth'
#  'RTBoth' 'Factory' 'RTBoth' 'Residential' 'RTBoth']
#
# Index: 85, newLabel: r, row: [0 'Monumental Core' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth'
#  'Residential' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth']
#
# Index: 86, newLabel: r, row: [0 'Mount Pleasant' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth'
#  'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 87, newLabel: r, row: [0 'Mount Vernon Square' 'Tourism' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth'
#  'RTBoth' 'RTBoth' 'RTBoth' 'Residential' 'Residential']
#
# Index: 88, newLabel: r, row: [0 'Mount Vernon Triangle' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth'
#  'Tourism' 'RTBoth' 'Residential' 'RTBoth' 'College' 'RTBoth']
#
# Index: 89, newLabel: r, row: [0 'NE Boundary' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'Factory'
#  'RTBoth' 'Residential' 'RTBoth' 'Residential' 'Residential']
#
# Index: 90, newLabel: r, row: [0 'Navy Yard' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth'
#  'RTBoth' 'Residential' 'RTBoth' 'RTBoth']
#
# Index: 91, newLabel: r, row: [0 'Naylor Gardens' 'Residential' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth'
#  'RTBoth' 'Residential' 'Residential' 'RTBoth' 'Residential']
#
# Index: 92, newLabel: r, row: [0 'Near Northeast' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth'
#  'RTBoth' 'Residential' 'Residential' 'RTBoth' 'RTBoth']
#
# Index: 93, newLabel: r, row: [0 'Near Southeast' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential'
#  'RTBoth' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth']
#
# Index: 94, newLabel: r, row: [0 'North Capitol Street' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth'
#  'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'Business' 'RTBoth']
#
# Index: 95, newLabel: r, row: [0 'North Cleveland Park' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth'
#  'RTBoth' 'RTBoth' 'Factory' 'RTBoth' 'Residential' 'RTBoth']
#
# Index: 96, newLabel: r, row: [0 'North Michigan Park' 'Residential' 'RTBoth' 'RTBoth' 'Residential'
#  'RTBoth' 'RTBoth' 'RTBoth' 'Factory' 'RTBoth' 'Residential']
#
# Index: 97, newLabel: r, row: [0 'Palisades' 'RTBoth' 'Residential' 'Residential' 'Business' 'RTBoth'
#  'RTBoth' 'RTBoth' 'Residential' 'RTBoth' 'Infrastructure']
#
# Index: 98, newLabel: r, row: [0 'Park View' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential' 'Residential'
#  'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 99, newLabel: r, row: [0 'Penn Branch' 'RTBoth' 'RTBoth' 'Residential' 'Residential' 'RTBoth'
#  'Residential' 'RTBoth' 'Factory' 'RTBoth' 'Residential']
#
# Index: 100, newLabel: r, row: [0 'Penn Quarter' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth'
#  'Residential' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 101, newLabel: r, row: [0 'Petworth' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential' 'Residential'
#  'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 102, newLabel: r, row: [0 'Pleasant Hill' 'RTBoth' 'RTBoth' 'Residential' 'Residential'
#  'Residential' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 103, newLabel: r, row: [0 'Pleasant Plains' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth'
#  'Residential' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 104, newLabel: r, row: [0 'Queens Chapel' 'Residential' 'RTBoth' 'Residential' 'Residential'
#  'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'Factory']
#
# Index: 105, newLabel: r, row: [0 'Randle Highlands' 'Infrastructure' 'Residential' 'RTBoth' 'RTBoth'
#  'RTBoth' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 106, newLabel: r, row: [0 'River Terrace' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth'
#  'RTBoth' 'Residential' 'RTBoth' 'Residential' 'RTBoth']
#
# Index: 107, newLabel: r, row: [0 'Shepherd Park' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth'
#  'RTBoth' 'Factory' 'RTBoth' 'Residential' 'Residential']
#
# Index: 108, newLabel: r, row: [0 'Shipley' 'Residential' 'RTBoth' 'Residential' 'RTBoth' 'Residential'
#  'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 109, newLabel: r, row: [0 'Skyland' 'RTBoth' 'RTBoth' 'Infrastructure' 'RTBoth' 'RTBoth' 'RTBoth'
#  'Residential' 'Residential' 'RTBoth' 'Factory']
#
# Index: 110, newLabel: r, row: [0 'South Central' 'Infrastructure' 'Residential' 'Residential' 'RTBoth'
#  'Residential' 'Residential' 'Residential' 'RTBoth' 'Factory' 'RTBoth']
#
# Index: 111, newLabel: t, row: [0 'Southwest Employment Area' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth'
#  'RTBoth' 'Tourism' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth']
#
# Index: 112, newLabel: r, row: [0 'Southwest/Waterfront' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth'
#  'Residential' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 113, newLabel: r, row: [0 'Spring Valley' 'Residential' 'Residential' 'Residential' 'RTBoth'
#  'RTBoth' 'Factory' 'RTBoth' 'Residential' 'RTBoth' 'Residential']
#
# Index: 114, newLabel: r, row: [0 'Stanton Park' 'Residential' 'Residential' 'RTBoth' 'RTBoth'
#  'Residential' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'Factory']
#
# Index: 115, newLabel: r, row: [0 'Stronghold' 'Residential' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth'
#  'RTBoth' 'RTBoth' 'Factory' 'Residential' 'RTBoth']
#
# Index: 116, newLabel: r, row: [0 'Takoma' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential' 'Residential'
#  'RTBoth' 'RTBoth' 'RTBoth' 'Residential' 'Residential']
#
# Index: 117, newLabel: r, row: [0 'Tenleytown' 'RTBoth' 'Residential' 'RTBoth' 'Residential'
#  'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 118, newLabel: r, row: [0 'Trinidad' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential'
#  'Factory' 'RTBoth' 'Residential' 'RTBoth' 'Residential']
#
# Index: 119, newLabel: r, row: [0 'Truxton Circle' 'RTBoth' 'Residential' 'Residential' 'RTBoth' 'RTBoth'
#  'RTBoth' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth']
#
# Index: 120, newLabel: r, row: [0 'Twining' 'Residential' 'RTBoth' 'Residential' 'RTBoth' 'Residential'
#  'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'Factory']
#
# Index: 121, newLabel: r, row: [0 'University Heights' 'RTBoth' 'RTBoth' 'Residential' 'Residential'
#  'RTBoth' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 122, newLabel: r, row: [0 'Van Ness' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth'
#  'RTBoth' 'RTBoth' 'Residential' 'RTBoth']
#
# Index: 123, newLabel: r, row: [0 'Washington Highlands' 'Residential' 'Residential' 'Residential'
#  'RTBoth' 'RTBoth' 'Residential' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth']
#
# Index: 124, newLabel: r, row: [0 'Wesley Heights' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth'
#  'Infrastructure' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential' 'Residential']
#
# Index: 125, newLabel: r, row: [0 'West End' 'Tourism' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth'
#  'RTBoth' 'Residential' 'RTBoth' 'Infrastructure']
#
# Index: 126, newLabel: r, row: [0 'Woodland' 'Residential' 'RTBoth' 'RTBoth' 'Tourism' 'RTBoth' 'RTBoth'
#  'Residential' 'Residential' 'RTBoth' 'RTBoth']
#
# Index: 127, newLabel: r, row: [0 'Woodland-Normanstone' 'RTBoth' 'RTBoth' 'Residential' 'RTBoth'
#  'RTBoth' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'RTBoth']
#
# Index: 128, newLabel: r, row: [0 'Woodley Park' 'RTBoth' 'Residential' 'RTBoth' 'RTBoth' 'Tourism'
#  'RTBoth' 'Residential' 'Tourism' 'Residential' 'Residential']
#
# Index: 129, newLabel: r, row: [0 'Woodridge' 'Residential' 'RTBoth' 'RTBoth' 'RTBoth' 'Residential'
#  'RTBoth' 'RTBoth' 'Factory' 'RTBoth' 'Residential']

# %%
neighborhoods_venues_sorted_relabelled
# Out:
#     Cluster Labels                  Neighborhood 1st Most Common Venue  \
# 0                r           16th Street Heights                RTBoth
# 1                r                  Adams Morgan                RTBoth
# 2                r      American University Park                RTBoth
# 3                r                     Arboretum                RTBoth
# 4                r                 Barnaby Woods           Residential
# 5                r                    Barry Farm                RTBoth
# 6                r                      Bellevue           Residential
# 7                r                       Benning                RTBoth
# 8                r                 Benning Ridge                RTBoth
# 9                r                  Bloomingdale                RTBoth
# 10               r                     Brentwood                RTBoth
# 11               r                    Brightwood                RTBoth
# 12               r               Brightwood Park                RTBoth
# 13               r                     Brookland           Residential
# 14               r           Burleith/Hillandale           Residential
# 15               r                     Burrville                RTBoth
# 16               r                 Buzzard Point           Residential
# 17               r                  Capitol Hill                RTBoth
# 18               r                  Capitol View                RTBoth
# 19               r                  Cardozo/Shaw                RTBoth
# 20               r                        Carver                RTBoth
# 21               r             Cathedral Heights                RTBoth
# 22               r                    Central NE                RTBoth
# 23               r                   Chevy Chase           Residential
# 24               r                     Chinatown                RTBoth
# 25               r                Cleveland Park                RTBoth
# 26               r              Columbia Heights                RTBoth
# 27               r              Congress Heights           Residential
# 28               r   Connecticut Avenue/K Street               Tourism
# 29               r                     Crestwood        Infrastructure
# 30               r                      Deanwood           Residential
# 31               r                      Douglass                RTBoth
# 32               r                      Downtown               Tourism
# 33               r                 Downtown East               Tourism
# 34               r                 Dupont Circle                RTBoth
# 35               r                   Dupont Park           Residential
# 36               r              Eastland Gardens                RTBoth
# 37               r                     Eckington                RTBoth
# 38               r                      Edgewood           Residential
# 39               r               Fairfax Village                RTBoth
# 40               r                      Fairlawn           Residential
# 41               r                  Foggy Bottom                RTBoth
# 42               r                  Forest Hills           Residential
# 43               r               Fort Davis Park                RTBoth
# 44               r                   Fort Dupont                RTBoth
# 45               r                  Fort Lincoln                RTBoth
# 46               r                   Fort McNair           Residential
# 47               r                  Fort Stanton           Residential
# 48               r                   Fort Totten           Residential
# 49               r             Foxhall Crescents                RTBoth
# 50               r               Foxhall Village                RTBoth
# 51               r            Friendship Heights                RTBoth
# 52               r              Garfield Heights                RTBoth
# 53               r                       Gateway           Residential
# 54               r  George Washington University                RTBoth
# 55               r                    Georgetown                RTBoth
# 56               r          Georgetown Reservoir                RTBoth
# 57               r                   Glover Park                RTBoth
# 58               r                    Grant Park                RTBoth
# 59               r                      Greenway           Residential
# 60               r                     Hawthorne              Business
# 61               r                     Hill East                RTBoth
# 62               r                     Hillcrest                RTBoth
# 63               r                     Hillsdale           Residential
# 64               r            Historic Anacostia                RTBoth
# 65               r             Howard University                RTBoth
# 66               r                      Ivy City               Tourism
# 67               r              Kalorama Heights                RTBoth
# 68               r                    Kenilworth                RTBoth
# 69               r                  Kingman Park                RTBoth
# 70               r         Knox Hill/Buena Vista           Residential
# 71               r                  Lamond Riggs           Residential
# 72               r                       Langdon                RTBoth
# 73               r                      Langston                RTBoth
# 74               r                Lanier Heights                RTBoth
# 75               r                 Le Droit Park                RTBoth
# 76               r               Lincoln Heights           Residential
# 77               r                  Lincoln Park                RTBoth
# 78               r             Logan Circle/Shaw                RTBoth
# 79               r                    Manor Park                RTBoth
# 80               r              Marshall Heights           Residential
# 81               r            Mass. Ave. Heights               Tourism
# 82               r                       Mayfair                RTBoth
# 83               r                McLean Gardens                RTBoth
# 84               r                 Michigan Park           Residential
# 85               r               Monumental Core                RTBoth
# 86               r                Mount Pleasant                RTBoth
# 87               r           Mount Vernon Square               Tourism
# 88               r         Mount Vernon Triangle           Residential
# 89               r                   NE Boundary           Residential
# 90               r                     Navy Yard                RTBoth
# 91               r                Naylor Gardens           Residential
# 92               r                Near Northeast                RTBoth
# 93               r                Near Southeast           Residential
# 94               r          North Capitol Street                RTBoth
# 95               r          North Cleveland Park                RTBoth
# 96               r           North Michigan Park           Residential
# 97               r                     Palisades                RTBoth
# 98               r                     Park View                RTBoth
# 99               r                   Penn Branch                RTBoth
# 100              r                  Penn Quarter                RTBoth
# 101              r                      Petworth                RTBoth
# 102              r                 Pleasant Hill                RTBoth
# 103              r               Pleasant Plains                RTBoth
# 104              r                 Queens Chapel           Residential
# 105              r              Randle Highlands        Infrastructure
# 106              r                 River Terrace           Residential
# 107              r                 Shepherd Park           Residential
# 108              r                       Shipley           Residential
# 109              r                       Skyland                RTBoth
# 110              r                 South Central        Infrastructure
# 111              r     Southwest Employment Area                RTBoth
# 112              r          Southwest/Waterfront                RTBoth
# 113              r                 Spring Valley           Residential
# 114              r                  Stanton Park           Residential
# 115              r                    Stronghold           Residential
# 116              r                        Takoma                RTBoth
# 117              r                    Tenleytown                RTBoth
# 118              r                      Trinidad           Residential
# 119              r                Truxton Circle                RTBoth
# 120              r                       Twining           Residential
# 121              r            University Heights                RTBoth
# 122              r                      Van Ness                RTBoth
# 123              r          Washington Highlands           Residential
# 124              r                Wesley Heights                RTBoth
# 125              r                      West End               Tourism
# 126              r                      Woodland           Residential
# 127              r          Woodland-Normanstone                RTBoth
# 128              r                  Woodley Park                RTBoth
# 129              r                     Woodridge           Residential
#
#     2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                  RTBoth                RTBoth                RTBoth
# 1                  RTBoth                RTBoth                RTBoth
# 2                  RTBoth           Residential                RTBoth
# 3                  RTBoth                RTBoth           Residential
# 4             Residential                RTBoth                RTBoth
# 5             Residential        Infrastructure                RTBoth
# 6             Residential           Residential                RTBoth
# 7             Residential                RTBoth                RTBoth
# 8                Business           Residential                RTBoth
# 9             Residential           Residential           Residential
# 10                 RTBoth                RTBoth                RTBoth
# 11                 RTBoth                RTBoth                RTBoth
# 12                 RTBoth                RTBoth           Residential
# 13                 RTBoth                RTBoth                RTBoth
# 14                 RTBoth           Residential           Residential
# 15            Residential           Residential                RTBoth
# 16                 RTBoth           Residential                RTBoth
# 17                 RTBoth           Residential                RTBoth
# 18               Business           Residential           Residential
# 19                 RTBoth                RTBoth                RTBoth
# 20            Residential           Residential                RTBoth
# 21                 RTBoth           Residential           Residential
# 22                 RTBoth                RTBoth                RTBoth
# 23            Residential           Residential           Residential
# 24                 RTBoth               Tourism                RTBoth
# 25                 RTBoth                RTBoth           Residential
# 26            Residential                RTBoth           Residential
# 27                 RTBoth           Residential           Residential
# 28                 RTBoth                RTBoth                RTBoth
# 29            Residential                RTBoth                RTBoth
# 30            Residential                RTBoth           Residential
# 31                 RTBoth           Residential                RTBoth
# 32                 RTBoth                RTBoth                RTBoth
# 33                 RTBoth           Residential                RTBoth
# 34                 RTBoth                RTBoth           Residential
# 35         Infrastructure                RTBoth           Residential
# 36            Residential                RTBoth                RTBoth
# 37                 RTBoth                RTBoth           Residential
# 38                 RTBoth           Residential                RTBoth
# 39               Business                RTBoth           Residential
# 40            Residential                RTBoth           Residential
# 41                 RTBoth               Tourism                RTBoth
# 42                 RTBoth                RTBoth                RTBoth
# 43                 RTBoth                RTBoth                RTBoth
# 44            Residential           Residential           Residential
# 45                 RTBoth                RTBoth                RTBoth
# 46                 RTBoth           Residential           Residential
# 47         Infrastructure                RTBoth                RTBoth
# 48                 RTBoth                RTBoth           Residential
# 49                College           Residential                RTBoth
# 50                 RTBoth                RTBoth           Residential
# 51                 RTBoth                RTBoth                RTBoth
# 52                 RTBoth           Residential                RTBoth
# 53                 RTBoth           Residential                RTBoth
# 54                Tourism                RTBoth                RTBoth
# 55                 RTBoth                RTBoth                RTBoth
# 56            Residential                RTBoth           Residential
# 57            Residential                RTBoth                RTBoth
# 58                 RTBoth           Residential                RTBoth
# 59            Residential                RTBoth                RTBoth
# 60               Business                RTBoth                RTBoth
# 61            Residential           Residential                RTBoth
# 62            Residential        Infrastructure                RTBoth
# 63            Residential           Residential                RTBoth
# 64                 RTBoth           Residential                RTBoth
# 65                 RTBoth                RTBoth           Residential
# 66                 RTBoth                RTBoth                RTBoth
# 67                 RTBoth           Residential                RTBoth
# 68                 RTBoth                RTBoth                RTBoth
# 69         Infrastructure           Residential                RTBoth
# 70            Residential           Residential           Residential
# 71            Residential                RTBoth                RTBoth
# 72                 RTBoth                RTBoth           Residential
# 73               Business           Residential                RTBoth
# 74                 RTBoth                RTBoth                RTBoth
# 75            Residential                RTBoth                RTBoth
# 76                Factory                RTBoth                RTBoth
# 77                 RTBoth                RTBoth                RTBoth
# 78                 RTBoth                RTBoth           Residential
# 79            Residential                RTBoth           Residential
# 80               Business               Tourism                RTBoth
# 81                 RTBoth                RTBoth                RTBoth
# 82                 RTBoth           Residential                RTBoth
# 83                 RTBoth           Residential                RTBoth
# 84                 RTBoth                RTBoth           Residential
# 85                 RTBoth                RTBoth                RTBoth
# 86                 RTBoth                RTBoth           Residential
# 87                 RTBoth                RTBoth                RTBoth
# 88                 RTBoth                RTBoth                RTBoth
# 89                 RTBoth                RTBoth                RTBoth
# 90                 RTBoth                RTBoth                RTBoth
# 91            Residential                RTBoth                RTBoth
# 92            Residential                RTBoth                RTBoth
# 93                 RTBoth                RTBoth                RTBoth
# 94            Residential                RTBoth                RTBoth
# 95            Residential                RTBoth                RTBoth
# 96                 RTBoth                RTBoth           Residential
# 97            Residential           Residential              Business
# 98                 RTBoth                RTBoth           Residential
# 99                 RTBoth           Residential           Residential
# 100                RTBoth                RTBoth                RTBoth
# 101                RTBoth                RTBoth           Residential
# 102                RTBoth           Residential           Residential
# 103                RTBoth                RTBoth           Residential
# 104                RTBoth           Residential           Residential
# 105           Residential                RTBoth                RTBoth
# 106                RTBoth                RTBoth                RTBoth
# 107                RTBoth                RTBoth                RTBoth
# 108                RTBoth           Residential                RTBoth
# 109                RTBoth        Infrastructure                RTBoth
# 110           Residential           Residential                RTBoth
# 111                RTBoth                RTBoth                RTBoth
# 112                RTBoth           Residential                RTBoth
# 113           Residential           Residential                RTBoth
# 114           Residential                RTBoth                RTBoth
# 115                RTBoth                RTBoth           Residential
# 116                RTBoth                RTBoth           Residential
# 117           Residential                RTBoth           Residential
# 118                RTBoth                RTBoth                RTBoth
# 119           Residential           Residential                RTBoth
# 120                RTBoth           Residential                RTBoth
# 121                RTBoth           Residential           Residential
# 122                RTBoth           Residential                RTBoth
# 123           Residential           Residential                RTBoth
# 124                RTBoth           Residential                RTBoth
# 125                RTBoth                RTBoth           Residential
# 126                RTBoth                RTBoth               Tourism
# 127                RTBoth           Residential                RTBoth
# 128           Residential                RTBoth                RTBoth
# 129                RTBoth                RTBoth                RTBoth
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0                  RTBoth                RTBoth               Tourism
# 1             Residential                RTBoth                RTBoth
# 2                  RTBoth               Factory                RTBoth
# 3                  RTBoth                RTBoth                RTBoth
# 4                  RTBoth                RTBoth               Factory
# 5                  RTBoth                RTBoth                RTBoth
# 6             Residential           Residential                RTBoth
# 7             Residential           Residential                RTBoth
# 8             Residential                RTBoth                RTBoth
# 9             Residential                RTBoth                RTBoth
# 10                 RTBoth           Residential                RTBoth
# 11            Residential                RTBoth                RTBoth
# 12                 RTBoth           Residential                RTBoth
# 13                Factory                RTBoth           Residential
# 14            Residential                RTBoth               Factory
# 15                 RTBoth           Residential                RTBoth
# 16                 RTBoth           Residential           Residential
# 17                 RTBoth           Residential           Residential
# 18                 RTBoth                RTBoth                RTBoth
# 19            Residential           Residential                RTBoth
# 20                 RTBoth           Residential              Business
# 21            Residential           Residential                RTBoth
# 22                 RTBoth                RTBoth                RTBoth
# 23                 RTBoth                RTBoth                RTBoth
# 24                 RTBoth                RTBoth                RTBoth
# 25                 RTBoth                RTBoth                RTBoth
# 26            Residential                RTBoth                RTBoth
# 27         Infrastructure           Residential                RTBoth
# 28                 RTBoth                RTBoth                RTBoth
# 29                 RTBoth               Factory                RTBoth
# 30                 RTBoth                RTBoth               Factory
# 31                 RTBoth           Residential                RTBoth
# 32                 RTBoth                RTBoth                RTBoth
# 33            Residential                RTBoth                RTBoth
# 34                 RTBoth                RTBoth           Residential
# 35                 RTBoth                RTBoth                RTBoth
# 36                 RTBoth               Factory                RTBoth
# 37            Residential                RTBoth               Factory
# 38            Residential                RTBoth                RTBoth
# 39                 RTBoth                RTBoth                RTBoth
# 40            Residential                RTBoth                RTBoth
# 41                 RTBoth                RTBoth                RTBoth
# 42                 RTBoth                RTBoth           Residential
# 43            Residential                RTBoth               Factory
# 44            Residential           Residential                RTBoth
# 45                 RTBoth           Residential                RTBoth
# 46            Residential                RTBoth           Residential
# 47            Residential                RTBoth                RTBoth
# 48                 RTBoth                RTBoth                RTBoth
# 49            Residential                RTBoth                RTBoth
# 50                 RTBoth           Residential           Residential
# 51                 RTBoth           Residential           Residential
# 52            Residential                RTBoth                RTBoth
# 53                 RTBoth              Business                RTBoth
# 54                 RTBoth                RTBoth           Residential
# 55                 RTBoth                RTBoth           Residential
# 56            Residential                RTBoth                RTBoth
# 57                 RTBoth                RTBoth           Residential
# 58                 RTBoth               Factory                RTBoth
# 59                Factory                RTBoth           Residential
# 60            Residential                RTBoth                RTBoth
# 61                 RTBoth               Factory                RTBoth
# 62            Residential           Residential                RTBoth
# 63                 RTBoth           Residential                RTBoth
# 64                 RTBoth                RTBoth           Residential
# 65                 RTBoth                RTBoth                RTBoth
# 66                 RTBoth                RTBoth                RTBoth
# 67                 RTBoth                RTBoth                RTBoth
# 68            Residential           Residential                RTBoth
# 69                 RTBoth           Residential                RTBoth
# 70                 RTBoth                RTBoth               Factory
# 71                 RTBoth                RTBoth           Residential
# 72            Residential               Factory                RTBoth
# 73            Residential                RTBoth           Residential
# 74                 RTBoth           Residential                RTBoth
# 75                 RTBoth                RTBoth                RTBoth
# 76            Residential           Residential                RTBoth
# 77                 RTBoth           Residential                RTBoth
# 78                 RTBoth                RTBoth                RTBoth
# 79                 RTBoth           Residential                RTBoth
# 80                Factory                RTBoth           Residential
# 81                 RTBoth                RTBoth                RTBoth
# 82                 RTBoth               Factory                RTBoth
# 83            Residential           Residential                RTBoth
# 84                 RTBoth                RTBoth               Factory
# 85                 RTBoth           Residential                RTBoth
# 86                 RTBoth           Residential                RTBoth
# 87                 RTBoth                RTBoth                RTBoth
# 88                Tourism                RTBoth           Residential
# 89                Factory                RTBoth           Residential
# 90                 RTBoth                RTBoth                RTBoth
# 91                 RTBoth                RTBoth           Residential
# 92                 RTBoth                RTBoth           Residential
# 93            Residential                RTBoth                RTBoth
# 94                 RTBoth                RTBoth                RTBoth
# 95                 RTBoth                RTBoth               Factory
# 96                 RTBoth                RTBoth                RTBoth
# 97                 RTBoth                RTBoth                RTBoth
# 98            Residential                RTBoth                RTBoth
# 99                 RTBoth           Residential                RTBoth
# 100                RTBoth                RTBoth           Residential
# 101           Residential                RTBoth                RTBoth
# 102           Residential                RTBoth           Residential
# 103                RTBoth           Residential           Residential
# 104           Residential                RTBoth                RTBoth
# 105                RTBoth           Residential                RTBoth
# 106                RTBoth                RTBoth           Residential
# 107                RTBoth                RTBoth               Factory
# 108           Residential                RTBoth                RTBoth
# 109                RTBoth                RTBoth           Residential
# 110           Residential           Residential           Residential
# 111                RTBoth               Tourism                RTBoth
# 112           Residential                RTBoth           Residential
# 113                RTBoth               Factory                RTBoth
# 114           Residential           Residential                RTBoth
# 115                RTBoth                RTBoth                RTBoth
# 116           Residential                RTBoth                RTBoth
# 117           Residential                RTBoth                RTBoth
# 118           Residential               Factory                RTBoth
# 119                RTBoth                RTBoth                RTBoth
# 120           Residential           Residential                RTBoth
# 121                RTBoth           Residential                RTBoth
# 122                RTBoth                RTBoth                RTBoth
# 123                RTBoth           Residential                RTBoth
# 124        Infrastructure                RTBoth                RTBoth
# 125                RTBoth                RTBoth                RTBoth
# 126                RTBoth                RTBoth           Residential
# 127                RTBoth           Residential                RTBoth
# 128               Tourism                RTBoth           Residential
# 129           Residential                RTBoth                RTBoth
#
#     8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0                  RTBoth           Residential            Residential
# 1                  RTBoth                RTBoth                 RTBoth
# 2             Residential                RTBoth            Residential
# 3             Residential                RTBoth                 RTBoth
# 4                  RTBoth           Residential                 RTBoth
# 5                 Factory                RTBoth            Residential
# 6                  RTBoth                RTBoth                 RTBoth
# 7                  RTBoth                RTBoth            Residential
# 8                  RTBoth               Factory                 RTBoth
# 9             Residential                RTBoth                 RTBoth
# 10            Residential           Residential                 RTBoth
# 11                 RTBoth                RTBoth                 RTBoth
# 12                 RTBoth                RTBoth            Residential
# 13                 RTBoth           Residential                 RTBoth
# 14                 RTBoth           Residential                 RTBoth
# 15                 RTBoth                RTBoth                Factory
# 16                 RTBoth           Residential                 RTBoth
# 17                 RTBoth                RTBoth                 RTBoth
# 18                Factory                RTBoth            Residential
# 19                 RTBoth                RTBoth                 RTBoth
# 20                 RTBoth                RTBoth                 RTBoth
# 21            Residential           Residential                 RTBoth
# 22                 RTBoth           Residential            Residential
# 23                 RTBoth               Factory                 RTBoth
# 24                 RTBoth                RTBoth                 RTBoth
# 25                 RTBoth                RTBoth                 RTBoth
# 26            Residential                RTBoth                 RTBoth
# 27         Infrastructure                RTBoth                Tourism
# 28            Residential                RTBoth                 RTBoth
# 29            Residential                RTBoth            Residential
# 30                 RTBoth           Residential                 RTBoth
# 31                 RTBoth           Residential                 RTBoth
# 32                 RTBoth                RTBoth                 RTBoth
# 33                 RTBoth                RTBoth                 RTBoth
# 34                 RTBoth                RTBoth                 RTBoth
# 35            Residential                RTBoth            Residential
# 36            Residential           Residential                 RTBoth
# 37                 RTBoth           Residential                 RTBoth
# 38                 RTBoth           Residential            Residential
# 39                 RTBoth                RTBoth                Factory
# 40                Factory                RTBoth            Residential
# 41                 RTBoth                RTBoth                 RTBoth
# 42                 RTBoth           Residential                 RTBoth
# 43                 RTBoth           Residential                 RTBoth
# 44                Factory                RTBoth            Residential
# 45                 RTBoth                RTBoth                 RTBoth
# 46            Residential                RTBoth                 RTBoth
# 47                Factory                RTBoth            Residential
# 48                Factory                RTBoth            Residential
# 49                 RTBoth           Residential                 RTBoth
# 50                 RTBoth                RTBoth                Factory
# 51                 RTBoth               Tourism                 RTBoth
# 52                Factory                RTBoth            Residential
# 53            Residential                RTBoth                 RTBoth
# 54                 RTBoth               College            Residential
# 55                 RTBoth                RTBoth            Residential
# 56                 RTBoth               Factory                 RTBoth
# 57                 RTBoth                RTBoth            Residential
# 58            Residential                RTBoth            Residential
# 59                 RTBoth           Residential                 RTBoth
# 60                Factory                RTBoth            Residential
# 61            Residential                RTBoth            Residential
# 62                 RTBoth                RTBoth                Factory
# 63                 RTBoth               Factory                 RTBoth
# 64                 RTBoth                RTBoth                 RTBoth
# 65                 RTBoth                RTBoth            Residential
# 66                 RTBoth               Factory                 RTBoth
# 67                 RTBoth                RTBoth                 RTBoth
# 68                Factory                RTBoth            Residential
# 69                 RTBoth               Factory                 RTBoth
# 70                 RTBoth           Residential                 RTBoth
# 71            Residential              Business                 RTBoth
# 72            Residential                RTBoth            Residential
# 73            Residential                RTBoth            Residential
# 74                 RTBoth                RTBoth                 RTBoth
# 75                 RTBoth                RTBoth                 RTBoth
# 76                 RTBoth                RTBoth            Residential
# 77            Residential                RTBoth                 RTBoth
# 78            Residential                RTBoth                 RTBoth
# 79                 RTBoth               Factory                 RTBoth
# 80                 RTBoth           Residential                 RTBoth
# 81            Residential           Residential            Residential
# 82            Residential                RTBoth            Residential
# 83                 RTBoth                RTBoth                 RTBoth
# 84                 RTBoth           Residential                 RTBoth
# 85            Residential                RTBoth                 RTBoth
# 86                 RTBoth                RTBoth                 RTBoth
# 87                 RTBoth           Residential            Residential
# 88                 RTBoth               College                 RTBoth
# 89                 RTBoth           Residential            Residential
# 90            Residential                RTBoth                 RTBoth
# 91            Residential                RTBoth            Residential
# 92            Residential                RTBoth                 RTBoth
# 93            Residential                RTBoth                 RTBoth
# 94                 RTBoth              Business                 RTBoth
# 95                 RTBoth           Residential                 RTBoth
# 96                Factory                RTBoth            Residential
# 97            Residential                RTBoth         Infrastructure
# 98                 RTBoth                RTBoth                 RTBoth
# 99                Factory                RTBoth            Residential
# 100                RTBoth                RTBoth                 RTBoth
# 101                RTBoth                RTBoth                 RTBoth
# 102                RTBoth                RTBoth                 RTBoth
# 103                RTBoth                RTBoth                 RTBoth
# 104                RTBoth                RTBoth                Factory
# 105                RTBoth                RTBoth                 RTBoth
# 106                RTBoth           Residential                 RTBoth
# 107                RTBoth           Residential            Residential
# 108                RTBoth                RTBoth                 RTBoth
# 109           Residential                RTBoth                Factory
# 110                RTBoth               Factory                 RTBoth
# 111           Residential                RTBoth                 RTBoth
# 112                RTBoth                RTBoth                 RTBoth
# 113           Residential                RTBoth            Residential
# 114                RTBoth                RTBoth                Factory
# 115               Factory           Residential                 RTBoth
# 116                RTBoth           Residential            Residential
# 117                RTBoth                RTBoth                 RTBoth
# 118           Residential                RTBoth            Residential
# 119           Residential                RTBoth                 RTBoth
# 120                RTBoth                RTBoth                Factory
# 121                RTBoth                RTBoth                 RTBoth
# 122                RTBoth           Residential                 RTBoth
# 123           Residential                RTBoth                 RTBoth
# 124                RTBoth           Residential            Residential
# 125           Residential                RTBoth         Infrastructure
# 126           Residential                RTBoth                 RTBoth
# 127                RTBoth                RTBoth                 RTBoth
# 128               Tourism           Residential            Residential
# 129               Factory                RTBoth            Residential

# %% [markdown]
# # KNN

# %% [markdown]
# Use KNN to cluster the neighborhoods into three groups by venue.

# %%
# set number of clusters
kclusters = 3

dc_grouped_clustering = dc_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(dc_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
dc_merged = dc

# merge dc_grouped with dc_data to add latitude/longitude for each neighborhood
dc_merged = dc_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

# %%
address = 'Washington,DC'

geolocator = Nominatim(user_agent="dc_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(dc_merged['Latitude'], dc_merged['Longitude'], dc_merged['Neighborhood'], dc_merged['Cluster Labels']):
    if (math.isnan(cluster)):
        clus = 3
    else: 
        clus = int(cluster)
    label = folium.Popup('Neighborhood: '+ str(poi) + ' Cluster: ' + str(clus), parse_html=True)


    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[clus-1],
        fill=True,
        fill_color=rainbow[clus-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
