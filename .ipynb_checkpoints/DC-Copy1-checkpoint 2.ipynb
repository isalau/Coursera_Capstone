# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
! pip install geopy
#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

import geocoder # import geocoder
import math
print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in /Users/isalau/miniconda3/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /Users/isalau/miniconda3/lib/python3.8/site-packages (from geopy) (1.50)
# Libraries imported.

# %%
CLIENT_ID = 'YA1V0ZT4RLWE3PVLWULDI0QLPHCUNN0BNXSOT5GS3P1EZR0G' # your Foursquare ID
CLIENT_SECRET = 'ITTIADOFH3REMVNUNONWLMRG0T2051ETQD5GCDGDXBWNRJY5' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: YA1V0ZT4RLWE3PVLWULDI0QLPHCUNN0BNXSOT5GS3P1EZR0G
# CLIENT_SECRET:ITTIADOFH3REMVNUNONWLMRG0T2051ETQD5GCDGDXBWNRJY5

# %%
path = "/Users/isalau/Documents/GitHub/Coursera_Capstone/Neighborhood_Labels.csv"
dc = pd.read_csv(path)

# %%
dc = dc.rename({'X': 'Longitude'}, axis='columns')
dc = dc.rename({'Y': 'Latitude'}, axis='columns')
dc = dc.rename({'NAME': 'Neighborhood'}, axis='columns')

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500, LIMIT=100):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):           
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
dc_venues = getNearbyVenues(names=dc['Neighborhood'],
                                   latitudes=dc['Latitude'],
                                   longitudes=dc['Longitude']
                                  )

# %%
categories = dc_venues['Venue Category'].to_frame()

# %%
categories.insert(1, 'Venue Count',0)

# %%
categories_count = categories.groupby('Venue Category').count()

# %%
categories_count.sort_values(by=['Venue Count'], ascending = False)
# Out:
#                                           Venue Count
# Venue Category
# Coffee Shop                                        94
# Pizza Place                                        71
# Hotel                                              69
# Sandwich Place                                     62
# American Restaurant                                56
# Park                                               56
# Convenience Store                                  52
# Liquor Store                                       52
# Grocery Store                                      45
# Italian Restaurant                                 43
# Café                                               40
# Bar                                                40
# Gym                                                35
# Mexican Restaurant                                 34
# Food Truck                                         34
# Gym / Fitness Center                               34
# Chinese Restaurant                                 33
# Bus Stop                                           28
# Pharmacy                                           28
# Bakery                                             28
# Mediterranean Restaurant                           27
# New American Restaurant                            26
# Deli / Bodega                                      25
# Seafood Restaurant                                 25
# Bank                                               24
# Indian Restaurant                                  21
# Cocktail Bar                                       20
# Rental Car Location                                20
# Intersection                                       20
# Restaurant                                         20
# Theater                                            20
# Yoga Studio                                        20
# Ice Cream Shop                                     20
# Thai Restaurant                                    19
# Plaza                                              18
# Spa                                                18
# Playground                                         18
# Fast Food Restaurant                               18
# Asian Restaurant                                   18
# Sushi Restaurant                                   18
# Burger Joint                                       17
# Bus Station                                        17
# Taco Place                                         17
# Farmers Market                                     17
# Salad Place                                        17
# Steakhouse                                         16
# Cosmetics Shop                                     15
# Southern / Soul Food Restaurant                    15
# Vegetarian / Vegan Restaurant                      14
# Shipping Store                                     14
# Art Museum                                         14
# BBQ Joint                                          14
# French Restaurant                                  13
# Wine Bar                                           13
# Pool                                               13
# Wine Shop                                          13
# Dog Run                                            13
# Fried Chicken Joint                                13
# Latin American Restaurant                          13
# Art Gallery                                        12
# Bookstore                                          12
# Donut Shop                                         12
# Garden                                             12
# Japanese Restaurant                                12
# Gas Station                                        11
# Museum                                             11
# Ramen Restaurant                                   11
# History Museum                                     11
# Women's Store                                      11
# Tennis Court                                       11
# Recreation Center                                  10
# Gift Shop                                          10
# Performing Arts Venue                              10
# Dive Bar                                            9
# Wings Joint                                         9
# Juice Bar                                           9
# Korean Restaurant                                   9
# Beer Garden                                         9
# Bike Rental / Bike Share                            9
# Boutique                                            9
# Exhibit                                             9
# Caribbean Restaurant                                9
# Salon / Barbershop                                  9
# Diner                                               9
# Department Store                                    9
# Monument / Landmark                                 8
# Hotel Bar                                           8
# Bagel Shop                                          8
# Furniture / Home Store                              8
# Vietnamese Restaurant                               8
# Ethiopian Restaurant                                8
# Portuguese Restaurant                               8
# Dance Studio                                        7
# Optical Shop                                        7
# Shopping Mall                                       7
# Music Venue                                         7
# Gastropub                                           7
# Greek Restaurant                                    7
# Clothing Store                                      7
# Video Store                                         7
# Pet Store                                           7
# Baseball Field                                      7
# Mobile Phone Shop                                   7
# Pub                                                 6
# Middle Eastern Restaurant                           6
# Market                                              6
# Sculpture Garden                                    6
# Cycle Studio                                        6
# Hostel                                              6
# Historic Site                                       6
# Discount Store                                      6
# Breakfast Spot                                      6
# Brewery                                             6
# Peruvian Restaurant                                 6
# Sporting Goods Shop                                 6
# Spanish Restaurant                                  6
# Eastern European Restaurant                         6
# Tapas Restaurant                                    6
# Movie Theater                                       6
# Science Museum                                      5
# Brazilian Restaurant                                5
# General Entertainment                               5
# Lounge                                              5
# Arts & Crafts Store                                 5
# Food                                                5
# Gourmet Shop                                        5
# Concert Hall                                        5
# Building                                            5
# South American Restaurant                           4
# Poke Place                                          4
# Whisky Bar                                          4
# Soccer Field                                        4
# Tea Room                                            4
# Supermarket                                         4
# Pedestrian Plaza                                    4
# Snack Place                                         4
# Turkish Restaurant                                  4
# Trail                                               4
# Track                                               4
# Metro Station                                       4
# Thrift / Vintage Store                              4
# Music Store                                         4
# Zoo Exhibit                                         4
# Falafel Restaurant                                  4
# Frozen Yogurt Shop                                  4
# Bed & Breakfast                                     4
# Cuban Restaurant                                    4
# Electronics Store                                   4
# Cupcake Shop                                        4
# Basketball Court                                    4
# General College & University                        3
# Belgian Restaurant                                  3
# Massage Studio                                      3
# Gay Bar                                             3
# Dessert Shop                                        3
# Drugstore                                           3
# Light Rail Station                                  3
# Big Box Store                                       3
# Food & Drink Shop                                   3
# Fish & Chips Shop                                   3
# Filipino Restaurant                                 3
# Neighborhood                                        3
# Nightclub                                           3
# Synagogue                                           3
# Tailor Shop                                         3
# Outdoor Sculpture                                   3
# Train Station                                       3
# Smoke Shop                                          3
# Harbor / Marina                                     3
# Laundromat                                          3
# Shoe Store                                          3
# Hot Dog Joint                                       3
# Indie Movie Theater                                 3
# Lake                                                3
# Scenic Lookout                                      3
# Basketball Stadium                                  3
# Irish Pub                                           3
# Business Service                                    3
# Check Cashing Service                               3
# Record Shop                                         2
# Supplement Shop                                     2
# Empanada Restaurant                                 2
# Soccer Stadium                                      2
# Dumpling Restaurant                                 2
# Cheese Shop                                         2
# Christmas Market                                    2
# Escape Room                                         2
# Pilates Studio                                      2
# Dry Cleaner                                         2
# Cantonese Restaurant                                2
# Burrito Place                                       2
# Construction & Landscaping                          2
# Salvadoran Restaurant                               2
# Camera Store                                        2
# Speakeasy                                           2
# Road                                                2
# Residential Building (Apartment / Condo)            2
# Storage Facility                                    2
# Bus Line                                            2
# Border Crossing                                     2
# Public Art                                          2
# Hospital                                            2
# Hookah Bar                                          2
# Leather Goods Store                                 2
# Toy / Game Store                                    2
# Athletics & Sports                                  2
# Government Building                                 2
# Insurance Office                                    2
# Hardware Store                                      2
# Beer Bar                                            2
# Winery                                              2
# Boat or Ferry                                       2
# Lingerie Store                                      2
# Tunnel                                              2
# German Restaurant                                   2
# Mattress Store                                      2
# Memorial Site                                       2
# Men's Store                                         2
# Frame Store                                         2
# Gym Pool                                            2
# Flower Shop                                         2
# Tour Provider                                       2
# Flea Market                                         2
# Antique Shop                                        2
# Nail Salon                                          2
# Field                                               2
# Skating Rink                                        2
# Bistro                                              2
# Office                                              2
# Afghan Restaurant                                   2
# Souvenir Shop                                       1
# Automotive Shop                                     1
# Smoothie Shop                                       1
# Arepa Restaurant                                    1
# Child Care Service                                  1
# Cajun / Creole Restaurant                           1
# Xinjiang Restaurant                                 1
# Tex-Mex Restaurant                                  1
# Warehouse Store                                     1
# Volleyball Court                                    1
# Sports Bar                                          1
# Sports Club                                         1
# Stables                                             1
# State / Provincial Park                             1
# Beer Store                                          1
# Tourist Information Center                          1
# Bubble Tea Shop                                     1
# Bridge                                              1
# Boxing Gym                                          1
# Bowling Green                                       1
# Botanical Garden                                    1
# Tiki Bar                                            1
# Credit Union                                        1
# Shopping Plaza                                      1
# Golf Course                                         1
# Opera House                                         1
# Noodle House                                        1
# Nightlife Spot                                      1
# Moving Target                                       1
# Food Service                                        1
# Miscellaneous Shop                                  1
# Fountain                                            1
# Martial Arts School                                 1
# Locksmith                                           1
# Gluten-free Restaurant                              1
# Lawyer                                              1
# Kitchen Supply Store                                1
# Other Repair Shop                                   1
# Kids Store                                          1
# Karaoke Bar                                         1
# Jewelry Store                                       1
# Gymnastics Gym                                      1
# Israeli Restaurant                                  1
# Accessories Store                                   1
# Health & Beauty Service                             1
# Hotel Pool                                          1
# Heliport                                            1
# Herbs & Spices Store                                1
# Home Service                                        1
# Organic Grocery                                     1
# Paper / Office Supplies Store                       1
# Chocolate Shop                                      1
# River                                               1
# Shop & Service                                      1
# Shoe Repair                                         1
# College Administrative Building                     1
# College Basketball Court                            1
# College Bookstore                                   1
# Scandinavian Restaurant                             1
# College Library                                     1
# College Quad                                        1
# College Stadium                                     1
# Roof Deck                                           1
# Rock Club                                           1
# Comedy Club                                         1
# Factory                                             1
# Reservoir                                           1
# Comfort Food Restaurant                             1
# Comic Shop                                          1
# Post Office                                         1
# Planetarium                                         1
# Photography Studio                                  1
# Photography Lab                                     1
# Pet Service                                         1
# Pet Café                                            1
# Event Service                                       1
# Event Space                                         1
# ATM                                                 1

# %%
dc_venues.groupby('Neighborhood').count()
# Out:
#                               Neighborhood Latitude  Neighborhood Longitude  \
# Neighborhood
# 16th Street Heights                              14                      14
# Adams Morgan                                     57                      57
# American University Park                          2                       2
# Arboretum                                        15                      15
# Barnaby Woods                                     4                       4
# Barry Farm                                        6                       6
# Bellevue                                          5                       5
# Benning                                          16                      16
# Benning Ridge                                     4                       4
# Bloomingdale                                     19                      19
# Brentwood                                        19                      19
# Brightwood                                       26                      26
# Brightwood Park                                  27                      27
# Brookland                                         1                       1
# Burleith/Hillandale                               4                       4
# Burrville                                         5                       5
# Buzzard Point                                    14                      14
# Capitol Hill                                     94                      94
# Capitol View                                      5                       5
# Cardozo/Shaw                                     78                      78
# Carver                                           20                      20
# Cathedral Heights                                19                      19
# Central NE                                       10                      10
# Chevy Chase                                       4                       4
# Chinatown                                       100                     100
# Cleveland Park                                    8                       8
# Columbia Heights                                 45                      45
# Congress Heights                                 11                      11
# Connecticut Avenue/K Street                      67                      67
# Crestwood                                         1                       1
# Deanwood                                          4                       4
# Douglass                                          8                       8
# Downtown                                         54                      54
# Downtown East                                    29                      29
# Dupont Circle                                    90                      90
# Dupont Park                                      13                      13
# Eastland Gardens                                  4                       4
# Eckington                                         4                       4
# Edgewood                                         13                      13
# Fairfax Village                                   6                       6
# Fairlawn                                          4                       4
# Foggy Bottom                                     33                      33
# Forest Hills                                      7                       7
# Fort Davis Park                                   4                       4
# Fort Dupont                                       4                       4
# Fort Lincoln                                     19                      19
# Fort McNair                                       6                       6
# Fort Stanton                                      4                       4
# Fort Totten                                       6                       6
# Foxhall Crescents                                14                      14
# Foxhall Village                                   5                       5
# Friendship Heights                               31                      31
# Garfield Heights                                  4                       4
# Gateway                                          10                      10
# George Washington University                     51                      51
# Georgetown                                       65                      65
# Georgetown Reservoir                              4                       4
# Glover Park                                      41                      41
# Grant Park                                        2                       2
# Greenway                                          1                       1
# Hawthorne                                         3                       3
# Hill East                                         3                       3
# Hillcrest                                         5                       5
# Hillsdale                                         5                       5
# Historic Anacostia                               14                      14
# Howard University                                24                      24
# Ivy City                                          8                       8
# Kalorama Heights                                  9                       9
# Kenilworth                                        5                       5
# Kingman Park                                      6                       6
# Knox Hill/Buena Vista                             4                       4
# Lamond Riggs                                     13                      13
# Langdon                                           5                       5
# Langston                                         15                      15
# Lanier Heights                                   40                      40
# Le Droit Park                                    57                      57
# Lincoln Heights                                   4                       4
# Lincoln Park                                      6                       6
# Logan Circle/Shaw                                40                      40
# Manor Park                                        6                       6
# Marshall Heights                                  3                       3
# Mass. Ave. Heights                               13                      13
# Mayfair                                           2                       2
# McLean Gardens                                   18                      18
# Michigan Park                                     3                       3
# Monumental Core                                  18                      18
# Mount Pleasant                                   27                      27
# Mount Vernon Square                             100                     100
# Mount Vernon Triangle                            37                      37
# NE Boundary                                       2                       2
# Navy Yard                                        39                      39
# Naylor Gardens                                   17                      17
# Near Northeast                                   52                      52
# Near Southeast                                   30                      30
# North Capitol Street                             26                      26
# North Cleveland Park                              3                       3
# North Michigan Park                               3                       3
# Palisades                                        11                      11
# Park View                                        36                      36
# Penn Branch                                       5                       5
# Penn Quarter                                    100                     100
# Petworth                                         17                      17
# Pleasant Hill                                     7                       7
# Pleasant Plains                                  28                      28
# Queens Chapel                                     6                       6
# Randle Highlands                                  6                       6
# River Terrace                                     9                       9
# Shepherd Park                                     4                       4
# Shipley                                           8                       8
# Skyland                                           7                       7
# South Central                                     5                       5
# Southwest Employment Area                        85                      85
# Southwest/Waterfront                             18                      18
# Spring Valley                                     2                       2
# Stanton Park                                      7                       7
# Stronghold                                        5                       5
# Takoma                                           25                      25
# Tenleytown                                       52                      52
# Trinidad                                          4                       4
# Truxton Circle                                   23                      23
# Twining                                           5                       5
# University Heights                               12                      12
# Van Ness                                         27                      27
# Washington Highlands                              7                       7
# Wesley Heights                                   13                      13
# West End                                         48                      48
# Woodland                                          5                       5
# Woodland-Normanstone                              5                       5
# Woodley Park                                     17                      17
# Woodridge                                         6                       6
#
#                               Venue  Venue Latitude  Venue Longitude  \
# Neighborhood
# 16th Street Heights              14              14               14
# Adams Morgan                     57              57               57
# American University Park          2               2                2
# Arboretum                        15              15               15
# Barnaby Woods                     4               4                4
# Barry Farm                        6               6                6
# Bellevue                          5               5                5
# Benning                          16              16               16
# Benning Ridge                     4               4                4
# Bloomingdale                     19              19               19
# Brentwood                        19              19               19
# Brightwood                       26              26               26
# Brightwood Park                  27              27               27
# Brookland                         1               1                1
# Burleith/Hillandale               4               4                4
# Burrville                         5               5                5
# Buzzard Point                    14              14               14
# Capitol Hill                     94              94               94
# Capitol View                      5               5                5
# Cardozo/Shaw                     78              78               78
# Carver                           20              20               20
# Cathedral Heights                19              19               19
# Central NE                       10              10               10
# Chevy Chase                       4               4                4
# Chinatown                       100             100              100
# Cleveland Park                    8               8                8
# Columbia Heights                 45              45               45
# Congress Heights                 11              11               11
# Connecticut Avenue/K Street      67              67               67
# Crestwood                         1               1                1
# Deanwood                          4               4                4
# Douglass                          8               8                8
# Downtown                         54              54               54
# Downtown East                    29              29               29
# Dupont Circle                    90              90               90
# Dupont Park                      13              13               13
# Eastland Gardens                  4               4                4
# Eckington                         4               4                4
# Edgewood                         13              13               13
# Fairfax Village                   6               6                6
# Fairlawn                          4               4                4
# Foggy Bottom                     33              33               33
# Forest Hills                      7               7                7
# Fort Davis Park                   4               4                4
# Fort Dupont                       4               4                4
# Fort Lincoln                     19              19               19
# Fort McNair                       6               6                6
# Fort Stanton                      4               4                4
# Fort Totten                       6               6                6
# Foxhall Crescents                14              14               14
# Foxhall Village                   5               5                5
# Friendship Heights               31              31               31
# Garfield Heights                  4               4                4
# Gateway                          10              10               10
# George Washington University     51              51               51
# Georgetown                       65              65               65
# Georgetown Reservoir              4               4                4
# Glover Park                      41              41               41
# Grant Park                        2               2                2
# Greenway                          1               1                1
# Hawthorne                         3               3                3
# Hill East                         3               3                3
# Hillcrest                         5               5                5
# Hillsdale                         5               5                5
# Historic Anacostia               14              14               14
# Howard University                24              24               24
# Ivy City                          8               8                8
# Kalorama Heights                  9               9                9
# Kenilworth                        5               5                5
# Kingman Park                      6               6                6
# Knox Hill/Buena Vista             4               4                4
# Lamond Riggs                     13              13               13
# Langdon                           5               5                5
# Langston                         15              15               15
# Lanier Heights                   40              40               40
# Le Droit Park                    57              57               57
# Lincoln Heights                   4               4                4
# Lincoln Park                      6               6                6
# Logan Circle/Shaw                40              40               40
# Manor Park                        6               6                6
# Marshall Heights                  3               3                3
# Mass. Ave. Heights               13              13               13
# Mayfair                           2               2                2
# McLean Gardens                   18              18               18
# Michigan Park                     3               3                3
# Monumental Core                  18              18               18
# Mount Pleasant                   27              27               27
# Mount Vernon Square             100             100              100
# Mount Vernon Triangle            37              37               37
# NE Boundary                       2               2                2
# Navy Yard                        39              39               39
# Naylor Gardens                   17              17               17
# Near Northeast                   52              52               52
# Near Southeast                   30              30               30
# North Capitol Street             26              26               26
# North Cleveland Park              3               3                3
# North Michigan Park               3               3                3
# Palisades                        11              11               11
# Park View                        36              36               36
# Penn Branch                       5               5                5
# Penn Quarter                    100             100              100
# Petworth                         17              17               17
# Pleasant Hill                     7               7                7
# Pleasant Plains                  28              28               28
# Queens Chapel                     6               6                6
# Randle Highlands                  6               6                6
# River Terrace                     9               9                9
# Shepherd Park                     4               4                4
# Shipley                           8               8                8
# Skyland                           7               7                7
# South Central                     5               5                5
# Southwest Employment Area        85              85               85
# Southwest/Waterfront             18              18               18
# Spring Valley                     2               2                2
# Stanton Park                      7               7                7
# Stronghold                        5               5                5
# Takoma                           25              25               25
# Tenleytown                       52              52               52
# Trinidad                          4               4                4
# Truxton Circle                   23              23               23
# Twining                           5               5                5
# University Heights               12              12               12
# Van Ness                         27              27               27
# Washington Highlands              7               7                7
# Wesley Heights                   13              13               13
# West End                         48              48               48
# Woodland                          5               5                5
# Woodland-Normanstone              5               5                5
# Woodley Park                     17              17               17
# Woodridge                         6               6                6
#
#                               Venue Category
# Neighborhood
# 16th Street Heights                       14
# Adams Morgan                              57
# American University Park                   2
# Arboretum                                 15
# Barnaby Woods                              4
# Barry Farm                                 6
# Bellevue                                   5
# Benning                                   16
# Benning Ridge                              4
# Bloomingdale                              19
# Brentwood                                 19
# Brightwood                                26
# Brightwood Park                           27
# Brookland                                  1
# Burleith/Hillandale                        4
# Burrville                                  5
# Buzzard Point                             14
# Capitol Hill                              94
# Capitol View                               5
# Cardozo/Shaw                              78
# Carver                                    20
# Cathedral Heights                         19
# Central NE                                10
# Chevy Chase                                4
# Chinatown                                100
# Cleveland Park                             8
# Columbia Heights                          45
# Congress Heights                          11
# Connecticut Avenue/K Street               67
# Crestwood                                  1
# Deanwood                                   4
# Douglass                                   8
# Downtown                                  54
# Downtown East                             29
# Dupont Circle                             90
# Dupont Park                               13
# Eastland Gardens                           4
# Eckington                                  4
# Edgewood                                  13
# Fairfax Village                            6
# Fairlawn                                   4
# Foggy Bottom                              33
# Forest Hills                               7
# Fort Davis Park                            4
# Fort Dupont                                4
# Fort Lincoln                              19
# Fort McNair                                6
# Fort Stanton                               4
# Fort Totten                                6
# Foxhall Crescents                         14
# Foxhall Village                            5
# Friendship Heights                        31
# Garfield Heights                           4
# Gateway                                   10
# George Washington University              51
# Georgetown                                65
# Georgetown Reservoir                       4
# Glover Park                               41
# Grant Park                                 2
# Greenway                                   1
# Hawthorne                                  3
# Hill East                                  3
# Hillcrest                                  5
# Hillsdale                                  5
# Historic Anacostia                        14
# Howard University                         24
# Ivy City                                   8
# Kalorama Heights                           9
# Kenilworth                                 5
# Kingman Park                               6
# Knox Hill/Buena Vista                      4
# Lamond Riggs                              13
# Langdon                                    5
# Langston                                  15
# Lanier Heights                            40
# Le Droit Park                             57
# Lincoln Heights                            4
# Lincoln Park                               6
# Logan Circle/Shaw                         40
# Manor Park                                 6
# Marshall Heights                           3
# Mass. Ave. Heights                        13
# Mayfair                                    2
# McLean Gardens                            18
# Michigan Park                              3
# Monumental Core                           18
# Mount Pleasant                            27
# Mount Vernon Square                      100
# Mount Vernon Triangle                     37
# NE Boundary                                2
# Navy Yard                                 39
# Naylor Gardens                            17
# Near Northeast                            52
# Near Southeast                            30
# North Capitol Street                      26
# North Cleveland Park                       3
# North Michigan Park                        3
# Palisades                                 11
# Park View                                 36
# Penn Branch                                5
# Penn Quarter                             100
# Petworth                                  17
# Pleasant Hill                              7
# Pleasant Plains                           28
# Queens Chapel                              6
# Randle Highlands                           6
# River Terrace                              9
# Shepherd Park                              4
# Shipley                                    8
# Skyland                                    7
# South Central                              5
# Southwest Employment Area                 85
# Southwest/Waterfront                      18
# Spring Valley                              2
# Stanton Park                               7
# Stronghold                                 5
# Takoma                                    25
# Tenleytown                                52
# Trinidad                                   4
# Truxton Circle                            23
# Twining                                    5
# University Heights                        12
# Van Ness                                  27
# Washington Highlands                       7
# Wesley Heights                            13
# West End                                  48
# Woodland                                   5
# Woodland-Normanstone                       5
# Woodley Park                              17
# Woodridge                                  6

# %%
print('There are {} uniques categories.'.format(len(dc_venues['Venue Category'].unique())))
# Out:
# There are 308 uniques categories.

# %%
# one hot encoding
dc_onehot = pd.get_dummies(dc_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
dc_onehot['Neighborhood'] = dc_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [dc_onehot.columns[-1]] + list(dc_onehot.columns[:-1])
dc_onehot = dc_onehot[fixed_columns]

# %%
dc_grouped = dc_onehot.groupby('Neighborhood').mean().reset_index()

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = dc_grouped['Neighborhood']

for ind in np.arange(dc_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(dc_grouped.iloc[ind, :], num_top_venues)

# %%
# set number of clusters
kclusters = 3

dc_grouped_clustering = dc_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(dc_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 0, 0, 0, 0, 0, 0, 0, 2, 0], dtype=int32)

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
dc_merged = dc

# merge dc_grouped with dc_data to add latitude/longitude for each neighborhood
dc_merged = dc_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

# %%
address = 'Washington,DC'

geolocator = Nominatim(user_agent="dc_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 38.8949924, -77.0365581.

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(dc_merged['Latitude'], dc_merged['Longitude'], dc_merged['Neighborhood'], dc_merged['Cluster Labels']):
    if (math.isnan(cluster)):
        clus = 3
    else: 
        clus = int(cluster)
    label = folium.Popup('Neighborhood: '+ str(poi) + ' Cluster: ' + str(clus), parse_html=True)


    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[clus-1],
        fill=True,
        fill_color=rainbow[clus-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_3130f14486ac479d90b147d699484ef9%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3130f14486ac479d90b147d699484ef9%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_3130f14486ac479d90b147d699484ef9%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_3130f14486ac479d90b147d699484ef9%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B38.8949924%2C-77.0365581%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...
