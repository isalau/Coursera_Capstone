# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
! pip install geopy
#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

import geocoder # import geocoder
import math
import re
print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in /Users/isalau/miniconda3/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /Users/isalau/miniconda3/lib/python3.8/site-packages (from geopy) (1.50)
# Libraries imported.

# %%
CLIENT_ID = 'YA1V0ZT4RLWE3PVLWULDI0QLPHCUNN0BNXSOT5GS3P1EZR0G' # your Foursquare ID
CLIENT_SECRET = 'ITTIADOFH3REMVNUNONWLMRG0T2051ETQD5GCDGDXBWNRJY5' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: YA1V0ZT4RLWE3PVLWULDI0QLPHCUNN0BNXSOT5GS3P1EZR0G
# CLIENT_SECRET:ITTIADOFH3REMVNUNONWLMRG0T2051ETQD5GCDGDXBWNRJY5

# %%
path = "/Users/isalau/Documents/GitHub/Coursera_Capstone/Neighborhood_Labels.csv"
dc = pd.read_csv(path)

# %%
dc = dc.rename({'X': 'Longitude'}, axis='columns')
dc = dc.rename({'Y': 'Latitude'}, axis='columns')
dc = dc.rename({'NAME': 'Neighborhood'}, axis='columns')

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500, LIMIT=100):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
names=dc['Neighborhood']
latitudes=dc['Latitude']
longitudes=dc['Longitude']
radius=500
LIMIT=100
for name, lat, lng in zip(names, latitudes, longitudes):            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]

# %%
path = "/Users/isalau/Documents/GitHub/Coursera_Capstone/dc_venues.csv"
dc_venues_from_csv= pd.read_csv(path)
dc_venues_from_csv.head()
dc_venues = dc_venues_from_csv

# %%
# dc_venues = getNearbyVenues(names=dc['Neighborhood'],
#                                    latitudes=dc['Latitude'],
#                                    longitudes=dc['Longitude']
#                                   )
# dc_venues.to_csv('dc_venues.csv', index=False, header=True)

# %%
dc_venues.groupby('Neighborhood').count()
print('There are {} uniques categories.'.format(len(dc_venues['Venue Category'].unique())))
# Out:
# There are 308 uniques categories.

# %%
# one hot encoding
dc_onehot = pd.get_dummies(dc_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
dc_onehot['Neighborhood'] = dc_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [dc_onehot.columns[-1]] + list(dc_onehot.columns[:-1])
dc_onehot = dc_onehot[fixed_columns]

# %%
dc_grouped = dc_onehot.groupby('Neighborhood').mean().reset_index()

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = dc_grouped['Neighborhood']

for ind in np.arange(dc_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(dc_grouped.iloc[ind, :], num_top_venues)

# %% [markdown]
# # Manully Cluster Neighborhoods

# %%
categories = dc_venues
cat = categories.drop(['Neighborhood Latitude','Neighborhood Longitude', 'Venue Latitude','Venue Longitude'], axis=1)
print('There are originally {} uniques categories.'.format(len(cat['Venue Category'].unique())))
# Out:
# There are originally 308 uniques categories.

# %% [markdown]
# General venue categories relabeled

# %%
#Residential
Grocery = ['Tea','Bakery','Bagel Shop','Candy Store','Chocolate Shop','Convenience Store','Cupcake Shop','Deli / Bodega','Dessert Shop','Donut Shop','Drugstore','Farmers Market','Food,Food & Drink Shop','Gourmet Shop','Grocery Store','Liquor Store','Market','Organic Grocery','Pharmacy','Smoothie Shop','Snack Place','Supermarket','Supplement Shop','Wine Shop','Beer Store']
Health = ['Chiropractor','Health & Beauty Service','Hospital','Massage Studio','Nail Salon','Spa','Salon / Barbershop']
Home = ['Dog Run','Dry Cleaner','Home Service','Laundromat','Locksmith','Moving Target','Other Repair Shop','Pet Service','Shoe Repair','Storage Facility','Tailor Shop','Residential Building (Apartment / Condo)']
Sports = ['Athletics & Sports','Baseball Field','Basketball Court','Basketball Stadium','Boxing Gym','Cycle Studio','Dance Studio','Field','Golf Course','Gym','Gym / Fitness Center','Gym Pool','Gymnastics Gym','Harbor / Marina','Heliport','Lake','Martial Arts School','Pilates Studio','Playground','Skating Rink','Soccer Field','Soccer Stadium','Sports Club','State / Provincial Park','Volleyball Court','Yoga Studio','Recreation Center','Track','Tennis Court']

#Residential/Tourism 
Shopping=['Accessories Store','Antique Shop','Arts & Crafts Store','Automotive Shop','Big Box Store','Bookstore','Boutique','Camera Store','Christmas Market','Clothing Store','Comic Shop','Cosmetics Shop','Department Store','Discount Store','Electronics Store','Flea Market','Flower Shop','Furniture / Home Store','Gift Shop','Hardware Store','Herbs & Spices Store','Jewelry Store','Kids Store','Kitchen Supply Store','Leather Goods Store','Lingerie Store','Mattress Store',"Men/'s Store",'Miscellaneous Shop','Mobile Phone Shop','Music Store','Optical Shop','Paper / Office Supplies Store','Pet Store','Photography Lab','Record Shop','Shipping Store','Shoe Store','Shop & Service','Shopping Mall','Shopping Plaza','Smoke Shop','Souvenir Shop','Sporting Goods Shop','Thrift / Vintage Store','Toy / Game Store','Video Store','Warehouse Store',"Women/'s Store"]
Bar = ['Bar','Beer Bar','Beer Garden','Brewery','Cocktail Bar','Dive Bar','Gastropub','Gay Bar','Irish Pub','Karaoke Bar','Pub','Speakeasy','Sports Bar','Thai Restaurant','Tiki Bar','Whisky Bar','Wine Bar']
Restaurant = ['Afghan Restaurant','American Restaurant','Arepa Restaurant','Asian Restaurant','BBQ Joint','Belgian Restaurant','Bistro','Brazilian Restaurant','Breakfast Spot','Burger Joint','Burrito Place','Café','Cafeteria','Cajun / Creole Restaurant','Cantonese Restaurant','Caribbean Restaurant','Cheese Shop','Chinese Restaurant','Coffee Shop','Comfort Food Restaurant','Cuban Restaurant','Diner','Dumpling Restaurant','Eastern European Restaurant','Empanada Restaurant','Ethiopian Restaurant','Falafel Restaurant','Fast Food Restaurant','Filipino Restaurant','Fish & Chips Shop','Food Court','Food Service','Food Truck','French Restaurant','Fried Chicken Joint','Frozen Yogurt Shop','German Restaurant','Gluten-free Restaurant','Greek Restaurant','Hot Dog Joint','Ice Cream Shop','Indian Restaurant','Israeli Restaurant','Italian Restaurant','Japanese Restaurant','Juice Bar','Korean Restaurant','Latin American Restaurant','Mediterranean Restaurant','Mexican Restaurant','Middle Eastern Restaurant','New American Restaurant','Noodle House','Peruvian Restaurant','Pizza Place','Poke Place','Portuguese Restaurant','Puerto Rican Restaurant','Ramen Restaurant','Restaurant','Salad Place','Salvadoran Restaurant','Sandwich Place','Scandinavian Restaurant','Seafood Restaurant','South American Restaurant','Southern / Soul Food Restaurant','Spanish Restaurant','Steakhouse','Street Food Gathering','Sushi Restaurant','Taco Place','Tapas Restaurant','Tea Room','Tex-Mex Restaurant','Turkish Restaurant','Vegetarian / Vegan Restaurant','Vietnamese Restaurant','Wings Joint','Xinjiang Restaurant']
Transportation = ['Bike Rental / Bike Share','Boat or Ferry','Border Crossing','Bridge','Bus Line','Bus Station','Bus Stop','Gas Station','Metro Station','Rental Car Location','Trail','Train Station','Tunnel']
Entertainment = ['Bowling','Hookah Bar','Lounge','Nightclub','Nightlife Spot','Roof Deck','Event Space']
Banking = ['ATM','Bank','Check Cashing Service','Credit Union','Banking']
Culture = ['Art Gallery','Art Museum','Botanical Garden','Comedy Club','Escape Room','Exhibit','Fountain','Garden','General Entertainment','Historic Site','History Museum','Indie Movie Theater','Memorial Site','Monument / Landmark','Movie Theater','Museum','Music Venue','Opera House','Outdoor Sculpture','Park','Pedestrian Plaza','Performing Arts Venue','Planetarium','Plaza','Public Art','Rock Club','Scenic Lookout','Science Museum','Sculpture Garden','Synagogue','Theater','Winery','Zoo Exhibit']

#Tourism
Lodging = ['Bed & Breakfast','Hostel','Hotel','Hotel Bar','Hotel Pool']

#Industrial
Infrastructure = ['Intersection','Reservoir','River','Road']
Business = ['Building','Business Service','Construction & Landscaping','Government Building','Insurance Office','Lawyer','Light Rail Station','Office','Post Office']

# %%
cat = cat.replace(to_replace= Grocery, value="Grocery", regex = True)
cat = cat.replace(to_replace= Health, value="Health", regex = True)
cat = cat.replace(to_replace= Home, value="Home", regex = True)
cat = cat.replace(to_replace= Sports, value="Sports", regex = True)

cat = cat.replace(to_replace= Shopping, value="Shopping", regex = True)
cat = cat.replace(to_replace= Restaurant, value="Restaurant", regex = True)
cat = cat.replace(to_replace= Bar, value="Bar", regex = True)
cat = cat.replace(to_replace= Transportation, value="Transportation", regex = True)
cat = cat.replace(to_replace= Entertainment, value="Entertainment", regex = True)
cat = cat.replace(to_replace= Banking, value="Banking", regex = True)
cat = cat.replace(to_replace= Culture, value="Culture", regex = True)


cat = cat.replace(to_replace= Lodging, value="Lodging", regex = True)

cat = cat.replace(to_replace= Infrastructure, value="Infrastructure", regex = True)
cat = cat.replace(to_replace= Business, value="Business", regex = True)

print('There are {} unique categories after dictionary switch.'.format(len(cat['Venue Category'].unique())))
print('There are {} unique categories after dictionary switch.'.format((cat['Venue Category'].unique())))
# Out:
# There are 61 unique categories after dictionary switch.
# There are ['Culture' 'Sports' 'Infrastructure' 'Grocery' 'Restaurant' 'Food' 'Home'
#  'Banking' 'Shopping' 'Health' "Women's Store" 'Lodging' 'Bar' 'Pool'
#  'Sports / Fitness Center' 'Flea Grocery' 'New Restaurant'
#  'Latin Restaurant' 'Healthnish Restaurant' 'Transportation'
#  'College Administrative Business' 'South Restaurant' 'Soccer Sports'
#  'Neighborhood' 'Business' 'Concert Hall' 'Entertainment'
#  'Child Care Service' 'Sculpture Culture' 'College Sports' "Men's Store"
#  'Grocery Room' 'Christmas Grocery' 'Tour Provider'
#  'General College & University' 'Barlic Art' 'Bankinging'
#  'Residential Business (Apartment / Condo)' 'Sports Pool'
#  'College Shopping' 'Stables' 'Food & Drink Shop' 'Sportsnastics Sports'
#  'Government Business' 'Event Healthce' 'Lodging Bar' 'College Quad'
#  'Entertainment Green' 'Pet Restaurant' 'Science Culture' 'Lodging Pool'
#  'Photography Studio' 'Frame Store' 'Tourist Information Center'
#  'Zoo Culture' 'Bubble Grocery Shop' 'College Stadium' 'College Library'
#  'Event Service' 'Factory' 'Post Business'] unique categories after dictionary switch.

# %%
#anything missed shuld be caught here

#Residential
cat = cat.replace(regex=r'.*Food.*', value="Grocery")
cat = cat.replace(regex=r'.*Grocery.*', value="Grocery")


cat = cat.replace(regex=r'.*Auto.*', value="Home")
cat = cat.replace(regex=r'.*School.*', value="Home")
cat = cat.replace(regex=r'.*Residential.*', value="Home")
cat = cat.replace(regex=r'.*Child.*', value="Home")
cat = cat.replace(regex=r'.*Care.*', value="Home")
cat = cat.replace(regex=r'.*Home.*', value="Home")
cat = cat.replace(regex=r'.*Neighborhood.*', value="Home")

cat = cat.replace(regex=r'.*Sports.*', value="Sports")
cat = cat.replace(regex=r'.*Studio.*', value="Sports")
cat = cat.replace(regex=r'.*Stables.*', value="Sports")
cat = cat.replace(regex=r'.*Store.*', value="Sports")

#Residential/Tourism
cat = cat.replace(regex=r'.*Bar.*', value="Bar")
cat = cat.replace(regex=r'.*Restaurant.*', value="Restaurant")

cat = cat.replace(regex=r'.*Men.*', value="Shopping")
cat = cat.replace(regex=r'.*Women.*', value="Shopping")

cat = cat.replace(regex=r'.*Culture.*', value="Culture")
cat = cat.replace(regex=r'.*Event.*', value="Culture")
cat = cat.replace(regex=r'.*Concert.*', value="Culture")
cat = cat.replace(regex=r'.*Art.*', value="Culture")

cat = cat.replace(regex=r'.*Pool.*', value="Entertainment")
cat = cat.replace(regex=r'.*Entertainment.*', value="Entertainment")


#Tourism 
cat = cat.replace(regex=r'.*Tour.*', value="Tourism")
cat = cat.replace(regex=r'.*Hotel.*', value="Lodging")

#Industrial 
cat = cat.replace(regex=r'.*College.*', value="College")
cat = cat.replace(regex=r'.*Business.*', value="Business")
cat = cat.replace(regex=r'.*Bank.*', value="Banking")

# %%
print('There are {} final unique categories.'.format(len(cat['Venue Category'].unique())))
print('There are {} final unique categories.'.format((cat['Venue Category'].unique())))
# Out:
# There are 17 final unique categories.
# There are ['Culture' 'Sports' 'Infrastructure' 'Grocery' 'Restaurant' 'Home'
#  'Banking' 'Shopping' 'Health' 'Lodging' 'Bar' 'Entertainment'
#  'Transportation' 'College' 'Business' 'Tourism' 'Factory'] final unique categories.

# %%
l = cat['Venue Category'].unique()
l
# Out:
# array(['Culture', 'Sports', 'Infrastructure', 'Grocery', 'Restaurant',
#        'Home', 'Banking', 'Shopping', 'Health', 'Lodging', 'Bar',
#        'Entertainment', 'Transportation', 'College', 'Business',
#        'Tourism', 'Factory'], dtype=object)

# %% [markdown]
# For every neighborhood assign it either Residential, Tourism or Industrial based on majority type of venue

# %%
labels = cat

# %%
print('There are {} final unique categories.'.format(len(labels['Venue Category'].unique())))
print('There are {} final unique categories.'.format((labels['Venue Category'].unique())))
# Out:
# There are 17 final unique categories.
# There are ['Culture' 'Sports' 'Infrastructure' 'Grocery' 'Restaurant' 'Home'
#  'Banking' 'Shopping' 'Health' 'Lodging' 'Bar' 'Entertainment'
#  'Transportation' 'College' 'Business' 'Tourism' 'Factory'] final unique categories.

# %%
labels = labels.replace(regex=r'Grocery|Health|Home|Sports', value="Residential")
labels = labels.replace(regex=r'Shopping|Bar|Restaurant|Culture|Banking|Entertainment|Transportation', value="RTBoth")
labels = labels.replace(regex=r'Lodging|Tourism', value="Tourism")
labels = labels.replace(regex=r'Business|Infrastructure|College|Factory', value="Industrial")

print('There are {} final unique categories.'.format(len(labels['Venue Category'].unique())))
print('There are {} final unique categories.'.format((labels['Venue Category'].unique())))
# Out:
# There are 4 final unique categories.
# There are ['RTBoth' 'Residential' 'Industrial' 'Tourism'] final unique categories.

# %%
def rename_labels(cat):
    #Residential
    Grocery = ['Tea','Bakery','Bagel Shop','Candy Store','Chocolate Shop','Convenience Store','Cupcake Shop','Deli / Bodega','Dessert Shop','Donut Shop','Drugstore','Farmers Market','Food,Food & Drink Shop','Gourmet Shop','Grocery Store','Liquor Store','Market','Organic Grocery','Pharmacy','Smoothie Shop','Snack Place','Supermarket','Supplement Shop','Wine Shop','Beer Store']
    Health = ['Chiropractor','Health & Beauty Service','Hospital','Massage Studio','Nail Salon','Spa','Salon / Barbershop']
    Home = ['Dog Run','Dry Cleaner','Home Service','Laundromat','Locksmith','Moving Target','Other Repair Shop','Pet Service','Shoe Repair','Storage Facility','Tailor Shop','Residential Building (Apartment / Condo)']
    Sports = ['Athletics & Sports','Baseball Field','Basketball Court','Basketball Stadium','Boxing Gym','Cycle Studio','Dance Studio','Field','Golf Course','Gym','Gym / Fitness Center','Gym Pool','Gymnastics Gym','Harbor / Marina','Heliport','Lake','Martial Arts School','Pilates Studio','Playground','Skating Rink','Soccer Field','Soccer Stadium','Sports Club','State / Provincial Park','Volleyball Court','Yoga Studio','Recreation Center','Track','Tennis Court']

    #Residential/Tourism 
    Shopping=['Accessories Store','Antique Shop','Arts & Crafts Store','Automotive Shop','Big Box Store','Bookstore','Boutique','Camera Store','Christmas Market','Clothing Store','Comic Shop','Cosmetics Shop','Department Store','Discount Store','Electronics Store','Flea Market','Flower Shop','Furniture / Home Store','Gift Shop','Hardware Store','Herbs & Spices Store','Jewelry Store','Kids Store','Kitchen Supply Store','Leather Goods Store','Lingerie Store','Mattress Store',"Men/'s Store",'Miscellaneous Shop','Mobile Phone Shop','Music Store','Optical Shop','Paper / Office Supplies Store','Pet Store','Photography Lab','Record Shop','Shipping Store','Shoe Store','Shop & Service','Shopping Mall','Shopping Plaza','Smoke Shop','Souvenir Shop','Sporting Goods Shop','Thrift / Vintage Store','Toy / Game Store','Video Store','Warehouse Store',"Women/'s Store"]
    Bar = ['Bar','Beer Bar','Beer Garden','Brewery','Cocktail Bar','Dive Bar','Gastropub','Gay Bar','Irish Pub','Karaoke Bar','Pub','Speakeasy','Sports Bar','Thai Restaurant','Tiki Bar','Whisky Bar','Wine Bar']
    Restaurant = ['Afghan Restaurant','American Restaurant','Arepa Restaurant','Asian Restaurant','BBQ Joint','Belgian Restaurant','Bistro','Brazilian Restaurant','Breakfast Spot','Burger Joint','Burrito Place','Café','Cafeteria','Cajun / Creole Restaurant','Cantonese Restaurant','Caribbean Restaurant','Cheese Shop','Chinese Restaurant','Coffee Shop','Comfort Food Restaurant','Cuban Restaurant','Diner','Dumpling Restaurant','Eastern European Restaurant','Empanada Restaurant','Ethiopian Restaurant','Falafel Restaurant','Fast Food Restaurant','Filipino Restaurant','Fish & Chips Shop','Food Court','Food Service','Food Truck','French Restaurant','Fried Chicken Joint','Frozen Yogurt Shop','German Restaurant','Gluten-free Restaurant','Greek Restaurant','Hot Dog Joint','Ice Cream Shop','Indian Restaurant','Israeli Restaurant','Italian Restaurant','Japanese Restaurant','Juice Bar','Korean Restaurant','Latin American Restaurant','Mediterranean Restaurant','Mexican Restaurant','Middle Eastern Restaurant','New American Restaurant','Noodle House','Peruvian Restaurant','Pizza Place','Poke Place','Portuguese Restaurant','Puerto Rican Restaurant','Ramen Restaurant','Restaurant','Salad Place','Salvadoran Restaurant','Sandwich Place','Scandinavian Restaurant','Seafood Restaurant','South American Restaurant','Southern / Soul Food Restaurant','Spanish Restaurant','Steakhouse','Street Food Gathering','Sushi Restaurant','Taco Place','Tapas Restaurant','Tea Room','Tex-Mex Restaurant','Turkish Restaurant','Vegetarian / Vegan Restaurant','Vietnamese Restaurant','Wings Joint','Xinjiang Restaurant']
    Transportation = ['Bike Rental / Bike Share','Boat or Ferry','Border Crossing','Bridge','Bus Line','Bus Station','Bus Stop','Gas Station','Metro Station','Rental Car Location','Trail','Train Station','Tunnel']
    Entertainment = ['Bowling','Hookah Bar','Lounge','Nightclub','Nightlife Spot','Roof Deck','Event Space']
    Banking = ['ATM','Bank','Check Cashing Service','Credit Union','Banking']
    Culture = ['Art Gallery','Art Museum','Botanical Garden','Comedy Club','Escape Room','Exhibit','Fountain','Garden','General Entertainment','Historic Site','History Museum','Indie Movie Theater','Memorial Site','Monument / Landmark','Movie Theater','Museum','Music Venue','Opera House','Outdoor Sculpture','Park','Pedestrian Plaza','Performing Arts Venue','Planetarium','Plaza','Public Art','Rock Club','Scenic Lookout','Science Museum','Sculpture Garden','Synagogue','Theater','Winery','Zoo Exhibit']

    #Tourism
    Lodging = ['Bed & Breakfast','Hostel','Hotel','Hotel Bar','Hotel Pool']

    #Industrial
    Infrastructure = ['Intersection','Reservoir','River','Road']
    Business = ['Building','Business Service','Construction & Landscaping','Government Building','Insurance Office','Lawyer','Light Rail Station','Office','Post Office']

    cat = cat.replace(to_replace= Grocery, value="Grocery", regex = True)
    cat = cat.replace(to_replace= Health, value="Health", regex = True)
    cat = cat.replace(to_replace= Home, value="Home", regex = True)
    cat = cat.replace(to_replace= Sports, value="Sports", regex = True)

    cat = cat.replace(to_replace= Shopping, value="Shopping", regex = True)
    cat = cat.replace(to_replace= Restaurant, value="Restaurant", regex = True)
    cat = cat.replace(to_replace= Bar, value="Bar", regex = True)
    cat = cat.replace(to_replace= Transportation, value="Transportation", regex = True)
    cat = cat.replace(to_replace= Entertainment, value="Entertainment", regex = True)
    cat = cat.replace(to_replace= Banking, value="Banking", regex = True)
    cat = cat.replace(to_replace= Culture, value="Culture", regex = True)


    cat = cat.replace(to_replace= Lodging, value="Lodging", regex = True)

    cat = cat.replace(to_replace= Infrastructure, value="Infrastructure", regex = True)
    cat = cat.replace(to_replace= Business, value="Business", regex = True)

    #Residential
    cat = cat.replace(regex=r'.*Food.*', value="Grocery")
    cat = cat.replace(regex=r'.*Grocery.*', value="Grocery")


    cat = cat.replace(regex=r'.*Auto.*', value="Home")
    cat = cat.replace(regex=r'.*School.*', value="Home")
    cat = cat.replace(regex=r'.*Residential.*', value="Home")
    cat = cat.replace(regex=r'.*Child.*', value="Home")
    cat = cat.replace(regex=r'.*Care.*', value="Home")
    cat = cat.replace(regex=r'.*Home.*', value="Home")
    cat = cat.replace(regex=r'.*Neighborhood.*', value="Home")

    cat = cat.replace(regex=r'.*Sports.*', value="Sports")
    cat = cat.replace(regex=r'.*Studio.*', value="Sports")
    cat = cat.replace(regex=r'.*Stables.*', value="Sports")
    cat = cat.replace(regex=r'.*Store.*', value="Sports")

    #Residential/Tourism
    cat = cat.replace(regex=r'.*Bar.*', value="Bar")
    cat = cat.replace(regex=r'.*Restaurant.*', value="Restaurant")

    cat = cat.replace(regex=r'.*Men.*', value="Shopping")
    cat = cat.replace(regex=r'.*Women.*', value="Shopping")

    cat = cat.replace(regex=r'.*Culture.*', value="Culture")
    cat = cat.replace(regex=r'.*Event.*', value="Culture")
    cat = cat.replace(regex=r'.*Concert.*', value="Culture")
    cat = cat.replace(regex=r'.*Art.*', value="Culture")

    cat = cat.replace(regex=r'.*Pool.*', value="Entertainment")
    cat = cat.replace(regex=r'.*Entertainment.*', value="Entertainment")


    #Tourism 
    cat = cat.replace(regex=r'.*Tour.*', value="Tourism")
    cat = cat.replace(regex=r'.*Hotel.*', value="Lodging")

    #Industrial 
    cat = cat.replace(regex=r'.*College.*', value="College")
    cat = cat.replace(regex=r'.*Business.*', value="Business")
    cat = cat.replace(regex=r'.*Bank.*', value="Banking")

    labels = labels.replace(regex=r'Grocery|Health|Home|Sports', value="Residential")
    labels = labels.replace(regex=r'Shopping|Bar|Restaurant|Culture|Banking|Entertainment|Transportation', value="RTBoth")
    labels = labels.replace(regex=r'Lodging|Tourism', value="Tourism")
    labels = labels.replace(regex=r'Business|Infrastructure|College|Factory', value="Industrial")

    return labels

# %% [markdown]
# ## Get

# %% [markdown]
# Run algorithm assigning weights for each neighorhood

# %%
# each neighborhood has an overall residential, industrial and tousit count
# each neighborhood has an overall label 
# for each neighborhood 
#     count how many residential, industrial and tousit establishments there are. 
#     if an establishment is labeled as rtboth it gets a point in both residential and tourist. 
#     neighborhood is assigned label based on majority of establishments. 
#     if tie, break arbitrarly ---> priint these 

# cluster neighborhoods based on labels

# %%
neighborhoods_venues_sorted
# Out:
#      Cluster Labels                  Neighborhood  \
# 0                 0           16th Street Heights
# 1                 0                  Adams Morgan
# 2                 0      American University Park
# 3                 0                     Arboretum
# 4                 0                 Barnaby Woods
# 5                 0                    Barry Farm
# 6                 0                      Bellevue
# 7                 0                       Benning
# 8                 2                 Benning Ridge
# 9                 0                  Bloomingdale
# 10                0                     Brentwood
# 11                0                    Brightwood
# 12                0               Brightwood Park
# 13                0                     Brookland
# 14                0           Burleith/Hillandale
# 15                2                     Burrville
# 16                0                 Buzzard Point
# 17                0                  Capitol Hill
# 18                2                  Capitol View
# 19                0                  Cardozo/Shaw
# 20                0                        Carver
# 21                0             Cathedral Heights
# 22                0                    Central NE
# 23                0                   Chevy Chase
# 24                0                     Chinatown
# 25                0                Cleveland Park
# 26                0              Columbia Heights
# 27                2              Congress Heights
# 28                0   Connecticut Avenue/K Street
# 29                0                     Crestwood
# 30                0                      Deanwood
# 31                0                      Douglass
# 32                0                      Downtown
# 33                0                 Downtown East
# 34                0                 Dupont Circle
# 35                2                   Dupont Park
# 36                0              Eastland Gardens
# 37                0                     Eckington
# 38                0                      Edgewood
# 39                2               Fairfax Village
# 40                2                      Fairlawn
# 41                0                  Foggy Bottom
# 42                0                  Forest Hills
# 43                0               Fort Davis Park
# 44                0                   Fort Dupont
# 45                0                  Fort Lincoln
# 46                0                   Fort McNair
# 47                0                  Fort Stanton
# 48                0                   Fort Totten
# 49                0             Foxhall Crescents
# 50                0               Foxhall Village
# 51                0            Friendship Heights
# 52                2              Garfield Heights
# 53                2                       Gateway
# 54                0  George Washington University
# 55                0                    Georgetown
# 56                0          Georgetown Reservoir
# 57                0                   Glover Park
# 58                0                    Grant Park
# 59                1                      Greenway
# 60                0                     Hawthorne
# 61                0                     Hill East
# 62                0                     Hillcrest
# 63                0                     Hillsdale
# 64                0            Historic Anacostia
# 65                0             Howard University
# 66                0                      Ivy City
# 67                0              Kalorama Heights
# 68                2                    Kenilworth
# 69                0                  Kingman Park
# 70                2         Knox Hill/Buena Vista
# 71                2                  Lamond Riggs
# 72                0                       Langdon
# 73                0                      Langston
# 74                0                Lanier Heights
# 75                0                 Le Droit Park
# 76                2               Lincoln Heights
# 77                0                  Lincoln Park
# 78                0             Logan Circle/Shaw
# 79                0                    Manor Park
# 80                0              Marshall Heights
# 81                0            Mass. Ave. Heights
# 82                0                       Mayfair
# 83                0                McLean Gardens
# 84                0                 Michigan Park
# 85                0               Monumental Core
# 86                0                Mount Pleasant
# 87                0           Mount Vernon Square
# 88                0         Mount Vernon Triangle
# 89                2                   NE Boundary
# 90                0                     Navy Yard
# 91                2                Naylor Gardens
# 92                0                Near Northeast
# 93                0                Near Southeast
# 94                0          North Capitol Street
# 95                0          North Cleveland Park
# 96                0           North Michigan Park
# 97                0                     Palisades
# 98                0                     Park View
# 99                2                   Penn Branch
# 100               0                  Penn Quarter
# 101               0                      Petworth
# 102               0                 Pleasant Hill
# 103               0               Pleasant Plains
# 104               2                 Queens Chapel
# 105               0              Randle Highlands
# 106               0                 River Terrace
# 107               2                 Shepherd Park
# 108               2                       Shipley
# 109               0                       Skyland
# 110               0                 South Central
# 111               0     Southwest Employment Area
# 112               0          Southwest/Waterfront
# 113               1                 Spring Valley
# 114               2                  Stanton Park
# 115               0                    Stronghold
# 116               0                        Takoma
# 117               0                    Tenleytown
# 118               0                      Trinidad
# 119               0                Truxton Circle
# 120               2                       Twining
# 121               0            University Heights
# 122               0                      Van Ness
# 123               0          Washington Highlands
# 124               0                Wesley Heights
# 125               0                      West End
# 126               0                      Woodland
# 127               0          Woodland-Normanstone
# 128               0                  Woodley Park
# 129               2                     Woodridge
#
#              1st Most Common Venue       2nd Most Common Venue  \
# 0                      Coffee Shop       Salvadoran Restaurant
# 1                            Diner    Mediterranean Restaurant
# 2               Italian Restaurant                   BBQ Joint
# 3                           Garden              Ice Cream Shop
# 4                            Field        Gym / Fitness Center
# 5                         Bus Stop            Basketball Court
# 6                    Grocery Store              Baseball Field
# 7                   Discount Store                Liquor Store
# 8                   Shipping Store            Insurance Office
# 9                         Bus Stop                 Yoga Studio
# 10                           Plaza                 Video Store
# 11              Chinese Restaurant                 Pizza Place
# 12                     Bus Station              Breakfast Spot
# 13                         Stables         Filipino Restaurant
# 14                   Deli / Bodega                 Beer Garden
# 15              Seafood Restaurant           Convenience Store
# 16                             Gym         Sporting Goods Shop
# 17                      Food Truck                         Bar
# 18              Chinese Restaurant                    Building
# 19                     Coffee Shop     New American Restaurant
# 20                  Sandwich Place               Grocery Store
# 21                        Bus Stop          Italian Restaurant
# 22                            Park           Fish & Chips Shop
# 23               Recreation Center               Grocery Store
# 24             American Restaurant                  Art Museum
# 25                 Thai Restaurant           Indian Restaurant
# 26                     Pizza Place           Convenience Store
# 27                    Liquor Store              Ice Cream Shop
# 28                           Hotel              Sandwich Place
# 29                    Intersection                 Yoga Studio
# 30                Basketball Court          Child Care Service
# 31                            Bank              Breakfast Spot
# 32                           Hotel                 Coffee Shop
# 33                           Hotel                  Food Truck
# 34              Italian Restaurant                 Pizza Place
# 35               Convenience Store                Intersection
# 36            Fast Food Restaurant           Recreation Center
# 37                   Train Station       Check Cashing Service
# 38                   Grocery Store              Sandwich Place
# 39                     Pizza Place                 Post Office
# 40                    Liquor Store               Deli / Bodega
# 41                         Theater       Performing Arts Venue
# 42                   Grocery Store       Performing Arts Venue
# 43                   Historic Site          Chinese Restaurant
# 44                  Cosmetics Shop              Baseball Field
# 45                    Optical Shop         Sporting Goods Shop
# 46               Convenience Store         Sporting Goods Shop
# 47               Recreation Center                Intersection
# 48                   Grocery Store               Memorial Site
# 49                            Café             College Stadium
# 50                            Park                       Trail
# 51                Department Store              Cosmetics Shop
# 52                            Park                 Wings Joint
# 53                    Liquor Store              Shipping Store
# 54                     Coffee Shop                       Hotel
# 55                     Coffee Shop         American Restaurant
# 56                      Food Truck               Deli / Bodega
# 57                     Pizza Place                     Dog Run
# 58                   Event Service                        Park
# 59                    Tennis Court                 Yoga Studio
# 60                Business Service  Construction & Landscaping
# 61                     Pizza Place                      Bakery
# 62                     Wings Joint                Tennis Court
# 63                             Gym           Convenience Store
# 64             American Restaurant     Comfort Food Restaurant
# 65            Caribbean Restaurant              Sandwich Place
# 66                           Hotel         Indie Movie Theater
# 67                  Scenic Lookout                  Steakhouse
# 68              Chinese Restaurant                        Park
# 69                            Park                Intersection
# 70               Convenience Store                Liquor Store
# 71                    Liquor Store              Baseball Field
# 72                            Park               Memorial Site
# 73             Fried Chicken Joint          Light Rail Station
# 74                     Coffee Shop                 Zoo Exhibit
# 75                             Bar                Liquor Store
# 76               Convenience Store                     Factory
# 77                     Pizza Place                    Bus Stop
# 78                             Bar                 Coffee Shop
# 79             Rental Car Location              Baseball Field
# 80                    Soccer Field                    Building
# 81                           Hotel          Italian Restaurant
# 82                  Cosmetics Shop                 Bus Station
# 83                      Food Truck           French Restaurant
# 84                           Field                        Park
# 85                Sculpture Garden         Monument / Landmark
# 86       Latin American Restaurant                        Café
# 87                           Hotel         American Restaurant
# 88                             Gym          Italian Restaurant
# 89                    Liquor Store         Filipino Restaurant
# 90                  Sandwich Place                 Coffee Shop
# 91               Convenience Store                Liquor Store
# 92                     Coffee Shop                 Yoga Studio
# 93            Gym / Fitness Center            Sushi Restaurant
# 94                  Sandwich Place                         Gym
# 95                        Bus Stop                       Track
# 96                        Gym Pool                Antique Shop
# 97             American Restaurant               Deli / Bodega
# 98              Seafood Restaurant                 Beer Garden
# 99                   Boat or Ferry                 Wings Joint
# 100            American Restaurant                  Art Museum
# 101                    Pizza Place      Thrift / Vintage Store
# 102                       Bus Stop          Seafood Restaurant
# 103                    Pizza Place                 Beer Garden
# 104                   Liquor Store          Chinese Restaurant
# 105                   Intersection        Gym / Fitness Center
# 106                  Grocery Store                 Gas Station
# 107                   Liquor Store            Department Store
# 108              Convenience Store       Performing Arts Venue
# 109           Fast Food Restaurant         Fried Chicken Joint
# 110                   Intersection           Convenience Store
# 111                     Food Truck              Sandwich Place
# 112                        Theater                  Food Truck
# 113                   Tennis Court          Athletics & Sports
# 114              Convenience Store                 Yoga Studio
# 115                  Grocery Store                        Park
# 116  Vegetarian / Vegan Restaurant                        Park
# 117                    Pizza Place           Convenience Store
# 118                  Moving Target              Breakfast Spot
# 119             Spanish Restaurant                     Dog Run
# 120              Convenience Store                  Restaurant
# 121                 Clothing Store                 Coffee Shop
# 122            Rental Car Location              Sandwich Place
# 123                  Grocery Store            Basketball Court
# 124                       Bus Stop                        Park
# 125                          Hotel                        Café
# 126              Recreation Center                 Art Gallery
# 127            Rental Car Location            Pedestrian Plaza
# 128                    Zoo Exhibit                      Bakery
# 129              Convenience Store          Chinese Restaurant
#
#              3rd Most Common Venue                     4th Most Common Venue  \
# 0                   Breakfast Spot                                  Bus Stop
# 1             Ethiopian Restaurant                                       Bar
# 2                      Yoga Studio                       Filipino Restaurant
# 3               Chinese Restaurant                          Basketball Court
# 4                             Park                                 BBQ Joint
# 5                     Intersection                             Metro Station
# 6                       Playground                               Pizza Place
# 7                       Restaurant                            Sandwich Place
# 8                Convenience Store                              Burger Joint
# 9                    Grocery Store                             Deli / Bodega
# 10                  Sandwich Place                              Cocktail Bar
# 11              Mexican Restaurant                            Cosmetics Shop
# 12              Chinese Restaurant                              Liquor Store
# 13                     Event Space                                   Exhibit
# 14                      Bagel Shop                                   Dog Run
# 15                            Food                         Fish & Chips Shop
# 16                        Heliport                                Food Truck
# 17                   Women's Store                       American Restaurant
# 18               Convenience Store                                      Food
# 19             American Restaurant                                       Bar
# 20                        Pharmacy                      Fast Food Restaurant
# 21                    Tennis Court                              Gourmet Shop
# 22                  Cosmetics Shop                      Caribbean Restaurant
# 23              Photography Studio                            Farmers Market
# 24                           Hotel                        Italian Restaurant
# 25             Xinjiang Restaurant                         Other Repair Shop
# 26                             Bar                                    Bakery
# 27                   Deli / Bodega                         Convenience Store
# 28                     Coffee Shop                                Steakhouse
# 29             Filipino Restaurant                               Event Space
# 30                   Metro Station                                Playground
# 31                             Spa                            Sandwich Place
# 32                      Steakhouse                       American Restaurant
# 33                          Bakery                       Monument / Landmark
# 34                 Thai Restaurant                                       Spa
# 35               Mobile Phone Shop                                  Pharmacy
# 36                       Bookstore                         Fish & Chips Shop
# 37                          Garden                               Yoga Studio
# 38                   Women's Store                        Seafood Restaurant
# 39                     Wings Joint                         Convenience Store
# 40                  Sandwich Place                               Yoga Studio
# 41                           Hotel                               Coffee Shop
# 42                  Shipping Store                            Sandwich Place
# 43                        Boutique                                 BBQ Joint
# 44                          Market                              Skating Rink
# 45                       Pet Store                        Mexican Restaurant
# 46                             Gym                            Soccer Stadium
# 47                            Park                                    Museum
# 48                            Park                                  Hospital
# 49                  Farmers Market                  Mediterranean Restaurant
# 50                     Bus Station                                      Lake
# 51                     Coffee Shop                       American Restaurant
# 52               Convenience Store                               Art Gallery
# 53                       Wine Shop                         Electronics Store
# 54                  Sandwich Place                                      Café
# 55                     Pizza Place                    Furniture / Home Store
# 56                           Trail                                      Lake
# 57                     Escape Room                                  Bus Stop
# 58                           Field                               Event Space
# 59             Filipino Restaurant                                   Exhibit
# 60           Performing Arts Venue                              Food Service
# 61                     Yoga Studio                             Event Service
# 62                    Intersection                            Sandwich Place
# 63                             Spa                             Jewelry Store
# 64                          Market                                     Diner
# 65              Mexican Restaurant                                  Gym Pool
# 66                     Art Gallery                               Bus Station
# 67            Gym / Fitness Center                                    Bistro
# 68                     Coffee Shop                           Border Crossing
# 69                   Deli / Bodega                                      Pool
# 70                   Grocery Store                                     Field
# 71             Rental Car Location                               Bus Station
# 72                     Bus Station                                   Dog Run
# 73                   Grocery Store                                      Café
# 74                       BBQ Joint                  Mediterranean Restaurant
# 75                    Cocktail Bar                           Thai Restaurant
# 76                  Sandwich Place                        Chinese Restaurant
# 77                            Park                               Coffee Shop
# 78              Mexican Restaurant                      Gym / Fitness Center
# 79                            Park                         Convenience Store
# 80                 Bed & Breakfast                         Fish & Chips Shop
# 81                  Shipping Store                         German Restaurant
# 82                     Yoga Studio                       Filipino Restaurant
# 83                             Gym                               Pizza Place
# 84                        Wine Bar                               Yoga Studio
# 85                          Garden                                 Gift Shop
# 86                 Thai Restaurant                               Yoga Studio
# 87                     Coffee Shop                        Italian Restaurant
# 88             American Restaurant                       Japanese Restaurant
# 89                     Event Space                                   Exhibit
# 90              Mexican Restaurant                            Clothing Store
# 91                  Sandwich Place                               Pizza Place
# 92   Vegetarian / Vegan Restaurant                                Taco Place
# 93                            Park                               Coffee Shop
# 94                            Café                                 Gift Shop
# 95                        Wine Bar                       Filipino Restaurant
# 96            Fast Food Restaurant                                     Field
# 97               Convenience Store                          Business Service
# 98                             Bar                             Grocery Store
# 99               Convenience Store                                Laundromat
# 100                        Theater                            History Museum
# 101                         Lounge                            Farmers Market
# 102              Convenience Store                              Dance Studio
# 103                    Coffee Shop                               Yoga Studio
# 104              Convenience Store  Residential Building (Apartment / Condo)
# 105                           Bank                            Sandwich Place
# 106                     Food Truck                             Shopping Mall
# 107                       Boutique                      Fast Food Restaurant
# 108                   Dance Studio                               Wings Joint
# 109                   Intersection                               Coffee Shop
# 110                 Massage Studio                               Bus Station
# 111                        Exhibit                            Science Museum
# 112                  Grocery Store                                      Park
# 113                    Yoga Studio                             Event Service
# 114                      BBQ Joint                                      Park
# 115                       Bus Stop                              Tennis Court
# 116                    Bus Station                                Donut Shop
# 117             Mexican Restaurant                               Frame Store
# 118            American Restaurant                          Asian Restaurant
# 119                    Flea Market                                      Café
# 120                       Pharmacy                  Bike Rental / Bike Share
# 121                  Grocery Store                         Recreation Center
# 122                    Dry Cleaner                        Italian Restaurant
# 123                           Food                        Seafood Restaurant
# 124                  Grocery Store                       American Restaurant
# 125                           Park                            Farmers Market
# 126                           Park                           Bed & Breakfast
# 127                            Gym                          Sculpture Garden
# 128                 Shipping Store                            Sandwich Place
# 129                    Gas Station                                  Bus Stop
#
#          5th Most Common Venue            6th Most Common Venue  \
# 0           Chinese Restaurant                             Park
# 1                          Spa                 Asian Restaurant
# 2                      Exhibit                          Factory
# 3         Fast Food Restaurant                 Botanical Garden
# 4                  Event Space                          Exhibit
# 5          Rental Car Location              Filipino Restaurant
# 6                  Shoe Repair                   Farmers Market
# 7                     Pharmacy                       Donut Shop
# 8                        Field                    Event Service
# 9            Convenience Store                         Dive Bar
# 10               Shopping Mall                    Grocery Store
# 11               Grocery Store                         Bus Stop
# 12              Cosmetics Shop                           Bakery
# 13                     Factory               Falafel Restaurant
# 14                 Yoga Studio              Filipino Restaurant
# 15          Chinese Restaurant                      Yoga Studio
# 16                     Brewery                   Soccer Stadium
# 17                 Coffee Shop                    Deli / Bodega
# 18                        Café              Filipino Restaurant
# 19                         Gym                    Grocery Store
# 20          Chinese Restaurant                     Liquor Store
# 21              Farmers Market                        Drugstore
# 22                 Flower Shop                      Bus Station
# 23        Ethiopian Restaurant                    Event Service
# 24    Mediterranean Restaurant                      Salad Place
# 25          Mexican Restaurant                       Steakhouse
# 26                         Gym                   Mattress Store
# 27                        Road                     Tennis Court
# 28                  Food Truck                      Pizza Place
# 29                     Exhibit                          Factory
# 30         Filipino Restaurant                          Exhibit
# 31                 Video Store                    Women's Store
# 32              Sandwich Place                French Restaurant
# 33               Deli / Bodega                        Irish Pub
# 34          Mexican Restaurant                Korean Restaurant
# 35          Seafood Restaurant         Bike Rental / Bike Share
# 36                     Exhibit                          Factory
# 37                       Field                          Exhibit
# 38               Deli / Bodega              Rental Car Location
# 39               Shopping Mall         Bike Rental / Bike Share
# 40                       Field                      Event Space
# 41                 Pizza Place                     Concert Hall
# 42                Optical Shop                      Video Store
# 43                 Yoga Studio                          Exhibit
# 44                 Yoga Studio                            Field
# 45        Fast Food Restaurant                  Supplement Shop
# 46             Harbor / Marina            General Entertainment
# 47                Dance Studio              Filipino Restaurant
# 48          Miscellaneous Shop                         Bus Stop
# 49                    Pharmacy                      Coffee Shop
# 50              Sandwich Place                      Yoga Studio
# 51           Mobile Phone Shop                     Dance Studio
# 52                 Yoga Studio              Filipino Restaurant
# 53                 Gas Station                 Business Service
# 54            Sushi Restaurant              American Restaurant
# 55       Vietnamese Restaurant                             Bank
# 56                 Yoga Studio             Fast Food Restaurant
# 57       Vietnamese Restaurant               Italian Restaurant
# 58                     Exhibit                          Factory
# 59                     Factory               Falafel Restaurant
# 60                       Field                      Event Space
# 61                     Exhibit                          Factory
# 62                  Playground                      Yoga Studio
# 63                 Bus Station                            Field
# 64                 Coffee Shop                Outdoor Sculpture
# 65   Middle Eastern Restaurant               Frozen Yogurt Shop
# 66                    Tiki Bar                   Ice Cream Shop
# 67            Sushi Restaurant                             Park
# 68                Liquor Store                            Field
# 69                  Taco Place                            Field
# 70                 Event Space                          Exhibit
# 71                  Smoke Shop                      Gas Station
# 72                 Yoga Studio                          Factory
# 73                Liquor Store               Chinese Restaurant
# 74            Asian Restaurant                       Playground
# 75               Hot Dog Joint                Korean Restaurant
# 76                 Yoga Studio                            Field
# 77    Bike Rental / Bike Share                     Liquor Store
# 78                    Wine Bar              American Restaurant
# 79        Caribbean Restaurant                      Yoga Studio
# 80                     Factory               Falafel Restaurant
# 81                        Bank              Dumpling Restaurant
# 82                     Exhibit                          Factory
# 83                     Dog Run                         Pharmacy
# 84                 Event Space                          Exhibit
# 85                      Bridge                  Harbor / Marina
# 86              Ice Cream Shop                              Spa
# 87     New American Restaurant                              Bar
# 88                       Hotel                 Ramen Restaurant
# 89                     Factory               Falafel Restaurant
# 90                  Taco Place                             Café
# 91                  Shoe Store                      Coffee Shop
# 92                        Park          New American Restaurant
# 93           Convenience Store                             Café
# 94         Monument / Landmark                             Pool
# 95                 Event Space                          Exhibit
# 96               Event Service                      Event Space
# 97          Belgian Restaurant                   Shipping Store
# 98                Liquor Store  Southern / Soul Food Restaurant
# 99    Bike Rental / Bike Share                      Yoga Studio
# 100                Pizza Place                      Salad Place
# 101              Grocery Store                      Gas Station
# 102                        Gym                   Sandwich Place
# 103                     Garden         College Basketball Court
# 104       Gym / Fitness Center             Fast Food Restaurant
# 105         Seafood Restaurant                   Farmers Market
# 106   Bike Rental / Bike Share                             Park
# 107          Fish & Chips Shop                          Exhibit
# 108               Liquor Store               Chinese Restaurant
# 109                       Bank            Check Cashing Service
# 110               Home Service                      Yoga Studio
# 111                Coffee Shop                            Hotel
# 112                   Pharmacy                Indian Restaurant
# 113                    Exhibit                          Factory
# 114                 Playground                Recreation Center
# 115                 Food Truck                 Department Store
# 116               Liquor Store                  Border Crossing
# 117       Gym / Fitness Center                      Coffee Shop
# 118                Flea Market                          Factory
# 119                Music Venue             Caribbean Restaurant
# 120               Liquor Store                      Yoga Studio
# 121        Rental Car Location                       Playground
# 122           Sushi Restaurant                           Garden
# 123           Asian Restaurant                     Liquor Store
# 124               Intersection                      Coffee Shop
# 125        American Restaurant                        Hotel Bar
# 126                     Museum                     Food Service
# 127          Outdoor Sculpture                      Yoga Studio
# 128            Bed & Breakfast                      Coffee Shop
# 129               Liquor Store              Filipino Restaurant
#
#          7th Most Common Venue       8th Most Common Venue  \
# 0              Bed & Breakfast            Greek Restaurant
# 1               Ice Cream Shop                 Coffee Shop
# 2           Falafel Restaurant              Farmers Market
# 3              Automotive Shop            Storage Facility
# 4                      Factory          Falafel Restaurant
# 5                      Exhibit                     Factory
# 6         Ethiopian Restaurant               Event Service
# 7                  Pizza Place        Fast Food Restaurant
# 8                  Event Space                     Exhibit
# 9                  Pizza Place                     Dog Run
# 10                         Bar                 Sports Club
# 11           Mobile Phone Shop                        Café
# 12                        Café         Fried Chicken Joint
# 13              Farmers Market        Fast Food Restaurant
# 14                     Factory          Falafel Restaurant
# 15        Fast Food Restaurant                 Event Space
# 16            Storage Facility       General Entertainment
# 17                         Spa          Italian Restaurant
# 18                     Exhibit                     Factory
# 19                Cocktail Bar                 Pizza Place
# 20          Light Rail Station                 Coffee Shop
# 21                       Trail                    Pharmacy
# 22               Metro Station        Fast Food Restaurant
# 23                 Event Space                     Exhibit
# 24                 Pizza Place                     Theater
# 25              Sandwich Place                        Park
# 26         Filipino Restaurant                    Pharmacy
# 27         Fried Chicken Joint                Intersection
# 28                        Bank                      Bakery
# 29          Falafel Restaurant              Farmers Market
# 30                     Factory          Falafel Restaurant
# 31              Cosmetics Shop                Food Service
# 32                Camera Store            Tapas Restaurant
# 33                      Museum                        Café
# 34          Salon / Barbershop                  Restaurant
# 35              Sandwich Place        Gym / Fitness Center
# 36          Falafel Restaurant              Farmers Market
# 37                     Factory          Falafel Restaurant
# 38            Department Store                    Bus Stop
# 39        Fast Food Restaurant                 Event Space
# 40                     Exhibit                     Factory
# 41                        Park                  Restaurant
# 42                   Wine Shop         Filipino Restaurant
# 43                     Factory          Falafel Restaurant
# 44                     Exhibit                     Factory
# 45              Shopping Plaza          Chinese Restaurant
# 46                 Yoga Studio              Farmers Market
# 47                     Exhibit                     Factory
# 48                     Exhibit                     Factory
# 49             Photography Lab                 Pizza Place
# 50              Farmers Market                 Event Space
# 51                 Yoga Studio        Kitchen Supply Store
# 52                     Exhibit                     Factory
# 53      Thrift / Vintage Store              Farmers Market
# 54                         Gym                 Pizza Place
# 55                      Bakery          Mexican Restaurant
# 56                 Event Space                     Exhibit
# 57                 Yoga Studio              Shipping Store
# 58          Falafel Restaurant              Farmers Market
# 59              Farmers Market        Fast Food Restaurant
# 60                     Exhibit                     Factory
# 61          Falafel Restaurant              Farmers Market
# 62        Fast Food Restaurant                 Event Space
# 63                 Event Space                     Exhibit
# 64           Convenience Store                 Art Gallery
# 65          Chinese Restaurant                   Bookstore
# 66                Antique Shop                 Event Space
# 67              History Museum                        Café
# 68                     Exhibit                     Factory
# 69                 Event Space                     Exhibit
# 70                     Factory          Falafel Restaurant
# 71     State / Provincial Park           Convenience Store
# 72          Falafel Restaurant              Farmers Market
# 73                         Gym                       Track
# 74                        Park     New American Restaurant
# 75                        Café                 Coffee Shop
# 76                 Event Space                     Exhibit
# 77                 Flower Shop                 Flea Market
# 78                    Dive Bar               Grocery Store
# 79        Fast Food Restaurant                     Exhibit
# 80              Farmers Market        Fast Food Restaurant
# 81                   BBQ Joint                Tennis Court
# 82          Falafel Restaurant              Farmers Market
# 83              Sandwich Place                 Coffee Shop
# 84                     Factory          Falafel Restaurant
# 85                Concert Hall                 Snack Place
# 86   South American Restaurant              Sandwich Place
# 87                       Plaza    Mediterranean Restaurant
# 88              Massage Studio                 Coffee Shop
# 89              Farmers Market        Fast Food Restaurant
# 90                   Juice Bar           Recreation Center
# 91               Grocery Store                         Gym
# 92               Grocery Store        Gym / Fitness Center
# 93                  Taco Place                 Supermarket
# 94                 Music Venue                  Food Truck
# 95                     Factory          Falafel Restaurant
# 96                     Exhibit                     Factory
# 97                        Bank              Pilates Studio
# 98          Chinese Restaurant            Tapas Restaurant
# 99                     Exhibit                     Factory
# 100         Basketball Stadium                      Museum
# 101                  BBQ Joint   Latin American Restaurant
# 102             Farmers Market               Event Service
# 103               Gourmet Shop          Chinese Restaurant
# 104              Event Service                 Event Space
# 105       Ethiopian Restaurant               Event Service
# 106               Dance Studio         Rental Car Location
# 107                    Factory          Falafel Restaurant
# 108       Fast Food Restaurant               Event Service
# 109                   Pharmacy                 Yoga Studio
# 110                      Field                     Exhibit
# 111        Rental Car Location        Gym / Fitness Center
# 112          Recreation Center         Rental Car Location
# 113         Falafel Restaurant              Farmers Market
# 114               Antique Shop                         ATM
# 115        Filipino Restaurant                     Factory
# 116         Chinese Restaurant        Caribbean Restaurant
# 117               Burger Joint                    Bus Stop
# 118         Falafel Restaurant              Farmers Market
# 119       Fast Food Restaurant              Farmers Market
# 120       Fast Food Restaurant                 Event Space
# 121               Food Service       Vietnamese Restaurant
# 122                Coffee Shop                Noodle House
# 123                Flower Shop                 Flea Market
# 124         Italian Restaurant               Shopping Mall
# 125          French Restaurant                 Yoga Studio
# 126          Food & Drink Shop                        Food
# 127         Falafel Restaurant               Event Service
# 128                        Gym  Tourist Information Center
# 129                    Exhibit                     Factory
#
#             9th Most Common Venue     10th Most Common Venue
# 0                             Gym             Gymnastics Gym
# 1                    Cocktail Bar       Brazilian Restaurant
# 2            Fast Food Restaurant                      Field
# 3                     Gas Station                  Nightclub
# 4                  Farmers Market       Fast Food Restaurant
# 5              Falafel Restaurant             Farmers Market
# 6                     Event Space                    Exhibit
# 7             Fried Chicken Joint                       Food
# 8                         Factory         Falafel Restaurant
# 9                     Coffee Shop                       Park
# 10                Organic Grocery        Sporting Goods Shop
# 11                    Gas Station              Big Box Store
# 12                    Cheese Shop                     Market
# 13                          Field          Fish & Chips Shop
# 14                 Farmers Market       Fast Food Restaurant
# 15                        Exhibit                    Factory
# 16                   Liquor Store              Souvenir Shop
# 17                    Pizza Place                       Park
# 18             Falafel Restaurant             Farmers Market
# 19       Mediterranean Restaurant  Latin American Restaurant
# 20                           Park                        Bar
# 21                        Dog Run                Bus Station
# 22                    Snack Place                      Field
# 23                        Factory         Falafel Restaurant
# 24                    Coffee Shop           Ramen Restaurant
# 25             Falafel Restaurant              Event Service
# 26      South American Restaurant   Mediterranean Restaurant
# 27            American Restaurant                     Hostel
# 28       Mediterranean Restaurant                  Hotel Bar
# 29           Fast Food Restaurant                      Field
# 30                 Farmers Market       Fast Food Restaurant
# 31              Food & Drink Shop                Event Space
# 32                        Theater   Mediterranean Restaurant
# 33              French Restaurant                 Steakhouse
# 34                   Cocktail Bar                Coffee Shop
# 35                           Bank               Liquor Store
# 36                          Field        Filipino Restaurant
# 37                 Farmers Market       Fast Food Restaurant
# 38                   Tennis Court                   Pharmacy
# 39                        Exhibit                    Factory
# 40             Falafel Restaurant             Farmers Market
# 41                 Sandwich Place         Chinese Restaurant
# 42                          Field       Fast Food Restaurant
# 43                 Farmers Market       Fast Food Restaurant
# 44             Falafel Restaurant             Farmers Market
# 45                 Sandwich Place                Coffee Shop
# 46                    Event Space                    Exhibit
# 47             Falafel Restaurant             Farmers Market
# 48             Falafel Restaurant             Farmers Market
# 49                      Wine Shop         Seafood Restaurant
# 50                        Exhibit                    Factory
# 51                          Hotel                Pizza Place
# 52             Falafel Restaurant             Farmers Market
# 53                  Event Service                Event Space
# 54                   College Quad                   Pharmacy
# 55                    Gas Station               Dessert Shop
# 56                        Factory         Falafel Restaurant
# 57               Sushi Restaurant               Liquor Store
# 58           Fast Food Restaurant                Yoga Studio
# 59                          Field          Fish & Chips Shop
# 60             Falafel Restaurant             Farmers Market
# 61           Fast Food Restaurant                      Field
# 62                        Exhibit                    Factory
# 63                        Factory         Falafel Restaurant
# 64                 Sandwich Place             History Museum
# 65                    Coffee Shop               Tennis Court
# 66                        Factory         Falafel Restaurant
# 67                     Whisky Bar        Filipino Restaurant
# 68             Falafel Restaurant             Farmers Market
# 69                        Factory         Falafel Restaurant
# 70                 Farmers Market       Fast Food Restaurant
# 71     Construction & Landscaping                Video Store
# 72           Fast Food Restaurant                      Field
# 73           Fast Food Restaurant                Golf Course
# 74      Middle Eastern Restaurant         Falafel Restaurant
# 75                    Pizza Place    New American Restaurant
# 76             Falafel Restaurant             Farmers Market
# 77              Fish & Chips Shop        Filipino Restaurant
# 78    Eastern European Restaurant            Thai Restaurant
# 79                        Factory         Falafel Restaurant
# 80                          Field        Filipino Restaurant
# 81                        Dog Run                 Playground
# 82           Fast Food Restaurant                      Field
# 83             Spanish Restaurant         Mexican Restaurant
# 84                 Farmers Market       Fast Food Restaurant
# 85                           Café                     Museum
# 86                    Pizza Place         Mexican Restaurant
# 87                   Liquor Store                     Bakery
# 88   General College & University                Salad Place
# 89                          Field                Yoga Studio
# 90                Thai Restaurant                    Brewery
# 91                           Bank               Tennis Court
# 92                    Bus Station               Burger Joint
# 93                        Brewery                 Food Truck
# 94                         Office         Seafood Restaurant
# 95                 Farmers Market       Fast Food Restaurant
# 96             Falafel Restaurant             Farmers Market
# 97                    Coffee Shop               Intersection
# 98                      Bookstore                   Boutique
# 99             Falafel Restaurant             Farmers Market
# 100              Tapas Restaurant    New American Restaurant
# 101           Japanese Restaurant         Mexican Restaurant
# 102                   Event Space                    Exhibit
# 103                     Bookstore         Seafood Restaurant
# 104                       Exhibit                    Factory
# 105                   Event Space                    Exhibit
# 106             Food & Drink Shop                Flower Shop
# 107                Farmers Market                      Field
# 108                   Event Space                    Exhibit
# 109                       Exhibit                    Factory
# 110                       Factory         Falafel Restaurant
# 111                        Museum               Burger Joint
# 112                   Coffee Shop                  Gastropub
# 113          Fast Food Restaurant                      Field
# 114                       Exhibit                    Factory
# 115                  Dance Studio         Falafel Restaurant
# 116                           Gym       Gym / Fitness Center
# 117                      Bus Line   Mediterranean Restaurant
# 118          Fast Food Restaurant                      Field
# 119            Chinese Restaurant             Sandwich Place
# 120                       Exhibit                    Factory
# 121     Latin American Restaurant                        Bar
# 122                        Market            Thai Restaurant
# 123             Fish & Chips Shop        Filipino Restaurant
# 124                  Gourmet Shop                  Drugstore
# 125                     Bookstore                       Road
# 126                   Flower Shop                 Food Truck
# 127                   Event Space                    Exhibit
# 128                         Track             Farmers Market
# 129            Falafel Restaurant             Farmers Market

# %%
t= rename_labels(['Culture' 'Sports' 'Infrastructure' 'Grocery' 'Restaurant' 'Food' 'Home'
 'Banking' 'Shopping' 'Health' "Women's Store" 'Lodging' 'Bar' 'Pool'
 'Sports / Fitness Center' 'Flea Grocery' 'New Restaurant'
 'Latin Restaurant' 'Healthnish Restaurant' 'Transportation'
 'College Administrative Business' 'South Restaurant' 'Soccer Sports'
 'Neighborhood' 'Business' 'Concert Hall' 'Entertainment'
 'Child Care Service' 'Sculpture Culture' 'College Sports' "Men's Store"
 'Grocery Room' 'Christmas Grocery' 'Tour Provider'
 'General College & University' 'Barlic Art' 'Bankinging'
 'Residential Business (Apartment / Condo)' 'Sports Pool'
 'College Shopping' 'Stables' 'Food & Drink Shop' 'Sportsnastics Sports'
 'Government Business' 'Event Healthce' 'Lodging Bar' 'College Quad'
 'Entertainment Green' 'Pet Restaurant' 'Science Culture' 'Lodging Pool'
 'Photography Studio' 'Frame Store' 'Tourist Information Center'
 'Zoo Culture' 'Bubble Grocery Shop' 'College Stadium' 'College Library'
 'Event Service' 'Factory' 'Post Business'])
t
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-0e7deadc4429> in <module>
# ----> 1 t= rename_labels(['Culture' 'Sports' 'Infrastructure' 'Grocery' 'Restaurant' 'Food' 'Home'
#       2  'Banking' 'Shopping' 'Health' "Women's Store" 'Lodging' 'Bar' 'Pool'
#       3  'Sports / Fitness Center' 'Flea Grocery' 'New Restaurant'
#       4  'Latin Restaurant' 'Healthnish Restaurant' 'Transportation'
#       5  'College Administrative Business' 'South Restaurant' 'Soccer Sports'
#
# <ipython-input-31-95bcc364d9b3> in rename_labels(cat)
#      22     Business = ['Building','Business Service','Construction & Landscaping','Government Building','Insurance Office','Lawyer','Light Rail Station','Office','Post Office']
#      23
# ---> 24     cat = cat.replace(to_replace= Grocery, value="Grocery", regex = True)
#      25     cat = cat.replace(to_replace= Health, value="Health", regex = True)
#      26     cat = cat.replace(to_replace= Home, value="Home", regex = True)
#
# AttributeError: 'list' object has no attribute 'replace'

# %% [markdown]
# # KNN

# %% [markdown]
# Use KNN to cluster the neighborhoods into three groups by venue.

# %%
# set number of clusters
kclusters = 3

dc_grouped_clustering = dc_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(dc_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 0, 0, 0, 0, 0, 0, 0, 2, 0], dtype=int32)

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
dc_merged = dc

# merge dc_grouped with dc_data to add latitude/longitude for each neighborhood
dc_merged = dc_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

# %%
address = 'Washington,DC'

geolocator = Nominatim(user_agent="dc_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 38.8949924, -77.0365581.

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(dc_merged['Latitude'], dc_merged['Longitude'], dc_merged['Neighborhood'], dc_merged['Cluster Labels']):
    if (math.isnan(cluster)):
        clus = 3
    else: 
        clus = int(cluster)
    label = folium.Popup('Neighborhood: '+ str(poi) + ' Cluster: ' + str(clus), parse_html=True)


    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[clus-1],
        fill=True,
        fill_color=rainbow[clus-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_9ae06f4c4971478580768dd2317a3d90%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_9ae06f4c4971478580768dd2317a3d90%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_9ae06f4c4971478580768dd2317a3d90%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_9ae06f4c4971478580768dd2317a3d90%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B38.8949924%2C-77.0365581%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...
